# %% [markdown]
# # Import Core Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import math

from os import listdir, walk
from os.path import isfile, join

# %% [markdown]
# # Load Dataset

# %%
# %run load_dataset.ipynb
# Out:
# Loading 1001's data
# Loading 1002's data
# Loading 1003's data
# Loading 1004's data
# Loading 1005's data
# Loading 1006's data
# Loading 1007's data
# Loading 1008's data
# Loading 1009's data
# Loading 1010's data
# Loading 1011's data
# Loading 1012's data
# Loading 2001's data
# Loading 2002's data
# Finished loading

# %% [markdown]
# # Data Preprocessing

# %%
# %run preprocess_for_SVM.ipynb
# includes wavelet denoising, normalization, PCA, LDA, SVD, etc.

# %%
print(X_all.shape, y_all.shape)
# Out:
# (27949, 3) (27949,)

# %% [markdown]
# # Group Data by Label and Normalize Data

# %%
print(label_list)
print(label_dict)
# Out:
# ['sit', 'sleep', 'stand', 'walk']
# {'sit': 0, 'sleep': 1, 'stand': 2, 'walk': 3}

# %%
# denoise the signal using wavelet transform
# wavelet_output = wavelet_smooth(X_all)
# X_w = np.array(wavelet_output)

# %%
new_label_list = [0,1,2,3]
new_label_dict = {
    0: 'sit',
    1: 'sleep',
    2: 'stand',
    3: 'walk'
}

colors = ['r','g','b','navy','turquoise','darkorange']

# %%
# group X_all and y_all from load_dataset.ipynb by labels
X_label, y_label = label_grouping(X_all, y_all, subj_all, new_label_list)

# normalize X_label
X_norm = normalize_data(X_label)

# %% [markdown]
# ## Show Plot for each Activity and Subject

# %%
plot_all_label(X_label, y_all, new_label_list, new_label_dict)
# Out:
# plotting  sit
# plotting  sleep
# plotting  stand
# plotting  walk

# %% [markdown]
# # Calculate Roll, Pitch, Yaw

# %%
roll, pitch, yaw = calc_rpy(X_all, subject_id, colors)
rpy = np.array([roll, pitch, yaw]).transpose()

print(rpy.shape)
# Out:
# (27949, 3)

# %% [markdown]
# # Apply PCA and LDA

# %%
# apply PCA and LDA to X_norm and rpy
X_pca = apply_pca(X_all, y_all, label_list)
rpy_pca = apply_pca(rpy, y_all, label_list)

# %%
X_lda = apply_lda(X_all, y_all, label_list)
rpy_lda = apply_pca(rpy, y_all, label_list)

# %% [markdown]
# # Reshape Data (Pure Label)

# %%
# get label-separated X and y
X_svm, y_svm = prepare_pure_label(X_pca, y_all, subj_all, new_label_list)
y_svm = y_svm.reshape((y_svm.shape[0],))

# %%
print(X_svm.shape, y_svm.shape)
# Out:
# (24645, 180) (24645,)

# %% [markdown]
# # Reshape Data (Impure Label)

# %%
X_impure, y_impure = prepare_impure_label(X_pca, y_all)

# %%
print(X_impure.shape, y_impure.shape)
# Out:
# (27890, 180) (27890,)

# %% [markdown]
# # Split Train and Test Set

# %%
# Split training data and testing data
X_train, X_test, y_train, y_test = train_test_split(X_svm, y_svm, test_size=0.3, random_state=42)

X_tr, X_te, y_tr, y_te = train_test_split(X_impure, y_impure, test_size=0.3, random_state=42)

print(X_tr.shape)
print(X_te.shape)
# Out:
# (19523, 180)
# (8367, 180)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (17251, 180)
# (7394, 180)

# %% [markdown]
# # SVM

# %%
svm_model = svm_classifier(X_train, y_train)
print("Finished training")
# Out:
# Finished training

# %%
y_pred_svm = svm_model.predict(X_test)

# %%
svm_model_2 = svm_classifier(X_tr, y_tr)
print("Finished training")
# Out:
# Finished training

# %% [markdown]
# ## SVM Evaluation

# %%
# %run eval_score.ipynb

# %%
LABELS = ['sit','sleep','stand','walk']

# %%
acc = accuracy_score(y_test, y_pred_svm)
print(acc)

show_conf_matrix(y_test, y_pred_svm, LABELS)
show_clf_report(y_test, y_pred_svm, LABELS)
# Out:
# 0.8685420611306465
#              precision    recall  f1-score   support
#
#         sit       0.86      0.92      0.89      1360
#       sleep       0.96      0.90      0.93      1268
#       stand       0.76      0.95      0.84      2098
#        walk       0.97      0.76      0.85      2668
#
# avg / total       0.89      0.87      0.87      7394

# %% [markdown]
# # Walk Algorithm

# %%
# %run classifier_alg.ipynb

# %%
# classify walking
walk = calc_walk(X_all)
walk_its = intersection_walk(walk)
walk_pred_p = calc_walk_periods(walk_its)

# walk_stairs_exact_p = get_exact_walk_stairs(y_all)
walk_exact_p = get_exact_walk(y_all)
    
walk_pred = binarize_walk_prd(walk_pred_p, y_all)
# walk_stairs_exact = binarize_walk_prd(walk_stairs_exact_p, y_all)
walk_exact = binarize_walk_prd(walk_exact_p, y_all)

# %% [markdown]
# ## Walk Algorithm Evaluation

# %%
walk_lbl = ['NaN','walk']

# %%
acc = accuracy_score(walk_exact, walk_pred)
print(acc)

show_conf_matrix(walk_exact, walk_pred, walk_lbl)
show_clf_report(walk_exact, walk_pred, walk_lbl)
# Out:
# 0.9217503309599628
#              precision    recall  f1-score   support
#
#         NaN       0.94      0.95      0.94     18941
#        walk       0.89      0.87      0.88      9008
#
# avg / total       0.92      0.92      0.92     27949

# %% [markdown]
# # Combine SVM and Walk Algorithm

# %%
y_pred_new = combine(X_test, y_pred_svm)

# %%
acc = accuracy_score(y_test, y_pred_new)
print(acc)

show_conf_matrix(y_test, y_pred_new, LABELS)
show_clf_report(y_test, y_pred_new, LABELS)
# Out:
# 0.9081687855017582
#              precision    recall  f1-score   support
#
#         sit       0.88      0.92      0.90      1360
#       sleep       0.96      0.90      0.93      1268
#       stand       0.84      0.95      0.89      2098
#        walk       0.97      0.87      0.92      2668
#
# avg / total       0.91      0.91      0.91      7394

# %% [markdown]
# # Test Model with Some Subject

# %%
# %run test_SVM_model.ipynb
# Out:
# Loading 1001's data
# Finished prediction
# Loading 1002's data
# Finished prediction
# Loading 1003's data
# Finished prediction
# Loading 1004's data
# Finished prediction
# Loading 1005's data
# Finished prediction
# Loading 1006's data
# Finished prediction
# Loading 1007's data
# Finished prediction
# Loading 2001's data
# Finished prediction
# Loading 2002's data
# Finished prediction

# %% [markdown]
# # Display Table

# %%
from prettytable import PrettyTable

# %%
labels_list = ['sit', 'sleep', 'stand', 'walk']
headers = ['start', 'end', 'pred']

t = PrettyTable(headers)

for row in label_period:
    if(calc_sec(row[1].split(' ')[1])-calc_sec(row[0].split(' ')[1])>1):
        t.add_row([row[0], row[1], labels_list[row[2]]])

# %%
print(t)
# Out:
# +-------------------------+-------------------------+-------+
# |          start          |           end           |  pred |
# +-------------------------+-------------------------+-------+
# |  2019-01-14 14:53:06.87 | 2019-01-14 14:53:11.531 |  walk |
# |  2019-01-14 14:53:11.69 | 2019-01-14 14:53:42.703 |  sit  |
# | 2019-01-14 14:53:43.508 | 2019-01-14 14:54:06.169 | stand |
# | 2019-01-14 14:54:06.652 | 2019-01-14 14:54:08.258 | stand |
# | 2019-01-14 14:54:08.741 | 2019-01-14 14:54:26.579 | stand |
# | 2019-01-14 14:54:29.473 |  2019-01-14 14:54:54.38 | stand |
# | 2019-01-14 14:54:55.826 | 2019-01-14 14:55:02.096 | stand |
# | 2019-01-14 14:55:02.255 | 2019-01-14 14:55:05.792 |  sit  |
# | 2019-01-14 14:55:05.954 | 2019-01-14 14:55:09.167 | stand |
# | 2019-01-14 14:55:09.327 | 2019-01-14 14:55:18.008 |  walk |
# | 2019-01-14 14:55:18.488 | 2019-01-14 14:55:51.438 | sleep |
# | 2019-01-14 14:55:51.599 | 2019-01-14 14:55:53.208 |  sit  |
# | 2019-01-14 14:55:53.529 | 2019-01-14 14:56:14.259 |  sit  |
# | 2019-01-14 14:56:14.419 | 2019-01-14 14:56:21.169 | stand |
# | 2019-01-14 14:56:21.974 | 2019-01-14 14:56:23.579 |  sit  |
# | 2019-01-14 14:56:25.026 | 2019-01-14 14:56:26.636 | stand |
# | 2019-01-14 14:56:26.794 |  2019-01-14 14:56:29.85 |  walk |
# | 2019-01-14 14:56:31.293 | 2019-01-14 14:57:04.084 | sleep |
# | 2019-01-14 14:57:04.405 | 2019-01-14 14:57:05.693 | sleep |
# | 2019-01-14 14:57:07.138 | 2019-01-14 14:57:11.317 |  walk |
# | 2019-01-14 14:57:11.639 | 2019-01-14 14:57:20.318 | stand |
# | 2019-01-14 14:57:20.479 | 2019-01-14 14:57:25.624 |  sit  |
# | 2019-01-14 14:57:25.783 | 2019-01-14 14:57:31.729 | stand |
# | 2019-01-14 14:57:32.065 | 2019-01-14 14:57:36.068 | stand |
# | 2019-01-14 14:57:36.229 | 2019-01-14 14:57:44.424 |  sit  |
# | 2019-01-14 14:57:44.585 | 2019-01-14 14:57:48.283 |  walk |
# | 2019-01-14 14:57:48.442 | 2019-01-14 14:57:53.263 | stand |
# | 2019-01-14 14:57:53.424 | 2019-01-14 14:57:54.871 |  walk |
# | 2019-01-14 14:57:55.031 | 2019-01-14 14:58:04.354 | stand |
# | 2019-01-14 14:58:07.087 | 2019-01-14 14:58:08.375 | stand |
# | 2019-01-14 14:58:09.981 | 2019-01-14 14:58:12.395 |  walk |
# | 2019-01-14 14:58:12.554 | 2019-01-14 14:58:18.501 | stand |
# | 2019-01-14 14:58:18.659 | 2019-01-14 14:58:25.412 |  sit  |
# |  2019-01-14 14:58:27.5  | 2019-01-14 14:58:32.645 | stand |
# | 2019-01-14 14:58:33.447 | 2019-01-14 14:58:43.414 | stand |
# | 2019-01-14 14:58:43.572 | 2019-01-14 14:59:02.538 |  sit  |
# | 2019-01-14 14:59:03.341 | 2019-01-14 14:59:05.752 |  sit  |
# | 2019-01-14 14:59:05.916 | 2019-01-14 14:59:09.295 | stand |
# | 2019-01-14 14:59:09.448 | 2019-01-14 14:59:10.574 |  sit  |
# | 2019-01-14 14:59:10.733 | 2019-01-14 14:59:12.024 | stand |
# | 2019-01-14 14:59:12.179 | 2019-01-14 15:00:21.447 |  walk |
# | 2019-01-14 15:00:21.927 | 2019-01-14 15:00:25.142 |  walk |
# | 2019-01-14 15:00:26.748 | 2019-01-14 15:00:31.088 |  walk |
# | 2019-01-14 15:00:31.248 | 2019-01-14 15:00:34.302 | stand |
# | 2019-01-14 15:00:35.749 | 2019-01-14 15:00:37.676 |  walk |
# | 2019-01-14 15:00:38.318 | 2019-01-14 15:01:16.088 |  sit  |
# | 2019-01-14 15:01:16.249 | 2019-01-14 15:01:18.499 |  walk |
# | 2019-01-14 15:01:18.659 | 2019-01-14 15:01:39.396 |  sit  |
# | 2019-01-14 15:01:39.557 | 2019-01-14 15:01:43.091 | stand |
# | 2019-01-14 15:01:43.254 | 2019-01-14 15:01:44.538 |  walk |
# | 2019-01-14 15:01:45.663 | 2019-01-14 15:02:02.699 |  walk |
# | 2019-01-14 15:02:03.342 | 2019-01-14 15:02:05.271 | stand |
# |  2019-01-14 15:02:05.43 | 2019-01-14 15:02:20.214 |  walk |
# | 2019-01-14 15:02:20.374 | 2019-01-14 15:02:21.984 | stand |
# | 2019-01-14 15:02:22.464 | 2019-01-14 15:03:03.121 |  walk |
# | 2019-01-14 15:03:03.604 | 2019-01-14 15:03:04.728 |  walk |
# | 2019-01-14 15:03:05.211 | 2019-01-14 15:03:06.336 |  walk |
# +-------------------------+-------------------------+-------+

# %%
df_sid[cols]
# Out:
#      sid                timestamp  duration  label
# 0   2002  2019-01-16 14:22:12.439  00:00:30  stand
# 1   2002  2019-01-16 14:22:46.157  00:00:30    sit
# 2   2002  2019-01-16 14:23:19.307  00:00:30  stand
# 3   2002  2019-01-16 14:24:05.584  00:00:30  sleep
# 4   2002  2019-01-16 14:24:44.454  00:00:30    sit
# 5   2002  2019-01-16 14:25:20.640  00:00:30  sleep
# 6   2002  2019-01-16 14:25:59.460  00:00:30  stand
# 7   2002  2019-01-16 14:26:42.431  00:00:30   walk
# 8   2002  2019-01-16 14:27:17.169  00:00:31   walk
# 9   2002  2019-01-16 14:28:22.139  00:00:23   walk
# 10  2002  2019-01-16 14:28:51.399  00:00:20   walk
# 11  2002  2019-01-16 14:29:15.654  00:00:21   walk
# 12  2002  2019-01-16 14:29:39.313  00:00:20   walk

# %% [markdown]
# # Predicted Duration

# %%
total_secs = []
for i in range(len(period_list)):    
    secs = 0
    for p_i in period_list[i]:
        sec = calc_sec(p_i[1].split(' ')[1]) - calc_sec(p_i[0].split(' ')[1])
        secs += sec
    
    secs = round(secs, 3)
    total_secs.append(secs)
    
percent_secs = [round(t/np.sum(total_secs)*100, 3) for t in total_secs]

tb = PrettyTable(['Label', 'Seconds', 'Percentage'])

for i in range(len(LABELS)):
    tb.add_row([labels_list[i], total_secs[i], percent_secs[i]])

tb.add_row(['', '', ''])
tb.add_row(['total', round(np.sum(total_secs), 3), round(np.sum(percent_secs), 3)])

# %% [markdown]
# # Actual Duration

# %%
df_lb = df_sid.groupby('label')
old_labels_list = ['sit', 'sleep', 'stand', 'walk']

dura_dict = {}
for lb in labels_list:
    dura_dict[lb] = 0

idx = list(df_sid.index)
for i in range(len(old_labels_list)):
    lb = old_labels_list[i]
    df_temp = df_lb.get_group(lb)
    df_temp = df_temp.reset_index(drop=True)
        
    if(lb=='downstairs' or lb=='upstairs'):
        lb = 'walk'
    
    for j in range(len(df_temp)):
        dura_dict[lb] += calc_sec(df_temp.loc[j]['duration'])

total_dura = np.sum([dura_dict[lb] for lb in labels_list])

percent_list = []
        
tabl = PrettyTable(['Label', 'Seconds', 'Percentage'])
for lb in labels_list:
    percent = round(dura_dict[lb]/total_dura*100, 3)
    tabl.add_row([lb, dura_dict[lb], round(dura_dict[lb]/total_dura*100, 3)])
    
    percent_list.append(percent)
    
tabl.add_row(['', '', ''])    
tabl.add_row(['total', round(total_dura, 3), np.sum(percent_list)])

# %% [markdown]
# # Activity Durations Table

# %%
print('Prediction')
print(tb)

print('Actual')
print(tabl)
# Out:
# Prediction
# +-------+---------+------------+
# | Label | Seconds | Percentage |
# +-------+---------+------------+
# |  sit  | 161.686 |   27.836   |
# | sleep |  67.832 |   11.678   |
# | stand | 160.875 |   27.696   |
# |  walk | 190.463 |   32.79    |
# |       |         |            |
# | total | 580.856 |   100.0    |
# +-------+---------+------------+
# Actual
# +-------+---------+------------+
# | Label | Seconds | Percentage |
# +-------+---------+------------+
# |  sit  |   60.0  |   16.901   |
# | sleep |   60.0  |   16.901   |
# | stand |   90.0  |   25.352   |
# |  walk |  145.0  |   40.845   |
# |       |         |            |
# | total |  355.0  |   99.999   |
# +-------+---------+------------+

# %% [markdown]
# # Bar Chart for Every 5 Minutes

# %%
s_idx = 0
f_idx = 1
lb_idx = 2

# %% [markdown]
# ## Separate Each 5 Minutes

# %%
fivemin = 60*5
new_label_period = []

start_time = calc_sec(label_period[0][s_idx].split(' ')[1])
finish_time = calc_sec(label_period[-1][f_idx].split(' ')[1])

floor_start = start_time - (start_time%fivemin)
ceil_finish = finish_time - (finish_time%fivemin) + fivemin

print(calc_ts(floor_start), calc_ts(ceil_finish))

tm_s = floor_start
tm_f = floor_start + fivemin
date = label_period[0][s_idx].split(' ')[0]

for prd in label_period:
    if(calc_sec(prd[f_idx].split(' ')[1])>=tm_f):
        new_prd = [prd[s_idx], date + ' ' + calc_ts(tm_f), prd[lb_idx]]
        new_label_period.append(new_prd)
        
        tm_s += fivemin
        tm_f += fivemin
    else:
        new_label_period.append(prd)
                
    if(calc_sec(prd[s_idx].split(' ')[1])<tm_s):
        new_prd = [date + ' ' + calc_ts(tm_s), prd[f_idx], prd[lb_idx]]
        new_label_period.append(new_prd)
# Out:
# 14:50:0.0 15:5:0.0

# %%
all_periods_label = []

for t_i in range(int(floor_start), int(ceil_finish), fivemin):
    period_lb = [0 for i in range(len(LABELS))]
    for prd in new_label_period:
        if(calc_sec(prd[s_idx].split(' ')[1])>=t_i and calc_sec(prd[f_idx].split(' ')[1])<=t_i+fivemin):
            period_lb[prd[lb_idx]] += calc_sec(prd[f_idx].split(' ')[1])-calc_sec(prd[s_idx].split(' ')[1])
            period_lb[prd[lb_idx]] = round(period_lb[prd[lb_idx]], 3)
            
    all_periods_label.append(period_lb)

# %%
df_all = pd.DataFrame(all_periods_label, columns=labels_list)

df_all
# Out:
#       sit   sleep   stand     walk
# 0  31.013   0.000  72.954    6.599
# 1  72.005  67.832  75.866   73.872
# 2  58.668   0.000  12.055  109.992

# %% [markdown]
# ## Plot Bar Graph

# %%
pos = list(range(len(df_all['sit'])))
width = 0.2
colors = ['crimson','gold','lime','dodgerblue']

fig, ax = plt.subplots(figsize=(10,5))

for i in range(len(LABELS)):
    plt.bar([p + i*width for p in pos],
            df_all[labels_list[i]],
            width,
            alpha=0.5,
            color=colors[i],
            label=labels_list[i])
    
ax.set_xticks([p + 1.5 * width for p in pos])

xtick_labels = [calc_ts(floor_start + i*fivemin) + '-' + calc_ts(floor_start + (i+1)*fivemin)
                for i in range(len(df_all))]
ax.set_xticklabels(xtick_labels)

ax.set_ylabel('Time (sec)')

plt.xlim(min(pos)-width, max(pos)+width*4)
plt.legend(loc='upper left')
plt.title('Activity Summary for Subject ID: ' + test_subj)

plt.show()
