# %% [markdown]
# # Import Core Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import math

from os import listdir, walk
from os.path import isfile, join

# %% [markdown]
# # Load Dataset

# %%
# %run load_dataset.ipynb
# Out:
# Loading 1001's data
# Loading 1002's data
# Loading 1003's data
# Loading 1004's data
# Loading 1005's data
# Loading 1006's data
# Loading 1007's data
# Loading 1008's data
# Loading 1009's data
# Loading 1010's data
# Loading 1011's data
# Loading 1012's data
# Loading 2001's data
# Loading 2002's data
# Finished loading

# %% [markdown]
# # Data Preprocessing

# %%
# %run preprocess_for_SVM.ipynb
# includes wavelet denoising, normalization, PCA, LDA, SVD, etc.

# %%
print(X_all.shape, y_all.shape)
# Out:
# (27949, 3) (27949,)

# %% [markdown]
# # Group Data by Label and Normalize Data

# %%
print(label_list)
print(label_dict)
# Out:
# ['sit', 'sleep', 'stand', 'walk']
# {'sit': 0, 'sleep': 1, 'stand': 2, 'walk': 3}

# %%
# denoise the signal using wavelet transform
# wavelet_output = wavelet_smooth(X_all)
# X_w = np.array(wavelet_output)

# %%
new_label_list = [0,1,2,3]
new_label_dict = {
    0: 'sit',
    1: 'sleep',
    2: 'stand',
    3: 'walk'
}

colors = ['r','g','b','navy','turquoise','darkorange']

# %%
# group X_all and y_all from load_dataset.ipynb by labels
X_label, y_label = label_grouping(X_all, y_all, subj_all, new_label_list)

# normalize X_label
X_norm = normalize_data(X_label)

# %% [markdown]
# ## Show Plot for each Activity and Subject

# %%
plot_all_label(X_label, y_all, new_label_list, new_label_dict)
# Out:
# plotting  sit
# plotting  sleep
# plotting  stand
# plotting  walk

# %% [markdown]
# # Calculate Roll, Pitch, Yaw

# %%
roll, pitch, yaw = calc_rpy(X_all, subject_id, colors)
rpy = np.array([roll, pitch, yaw]).transpose()

print(rpy.shape)
# Out:
# (27949, 3)

# %% [markdown]
# # Apply PCA and LDA

# %%
# apply PCA and LDA to X_norm and rpy
X_pca = apply_pca(X_all, y_all, label_list)
rpy_pca = apply_pca(rpy, y_all, label_list)

# %%
X_lda = apply_lda(X_all, y_all, label_list)
rpy_lda = apply_pca(rpy, y_all, label_list)

# %% [markdown]
# # Reshape Data (Pure Label)

# %%
# get label-separated X and y
X_svm, y_svm = prepare_pure_label(X_pca, y_all, subj_all, new_label_list)
y_svm = y_svm.reshape((y_svm.shape[0],))

# %%
print(X_svm.shape, y_svm.shape)
# Out:
# (24645, 180) (24645,)

# %% [markdown]
# # Reshape Data (Impure Label)

# %%
X_impure, y_impure = prepare_impure_label(X_pca, y_all)

# %%
print(X_impure.shape, y_impure.shape)
# Out:
# (27890, 180) (27890,)

# %% [markdown]
# # Split Train and Test Set

# %%
# Split training data and testing data
X_train, X_test, y_train, y_test = train_test_split(X_svm, y_svm, test_size=0.3, random_state=42)

X_tr, X_te, y_tr, y_te = train_test_split(X_impure, y_impure, test_size=0.3, random_state=42)

print(X_tr.shape)
print(X_te.shape)
# Out:
# (19523, 180)
# (8367, 180)

# %% [markdown]
# # SVM

# %%
svm_model = svm_classifier(X_tr, y_tr)
print("Finished training")
# Out:
# Finished training

# %%
y_pred_svm = svm_model.predict(X_te)

# %% [markdown]
# ## SVM Evaluation

# %%
# %run eval_score.ipynb

# %%
LABELS = ['sit','sleep','stand','walk']

# %%
acc = accuracy_score(y_te, y_pred_svm)
print(acc)

show_conf_matrix(y_te, y_pred_svm, LABELS)
show_clf_report(y_te, y_pred_svm, LABELS)
# Out:
# 0.835424883470778
#               precision    recall  f1-score   support
#
#          sit       0.79      0.84      0.82      1565
#        sleep       0.93      0.87      0.90      1534
#        stand       0.73      0.94      0.82      2351
#         walk       0.95      0.73      0.83      2917
#
#    micro avg       0.84      0.84      0.84      8367
#    macro avg       0.85      0.85      0.84      8367
# weighted avg       0.86      0.84      0.84      8367

# %% [markdown]
# # K-NN

# %%
nn_model = nn_classifier(X_train, y_train)
print("Finished training")
# Out:
# Finished training

# %%
y_pred_nn = nn_model.predict(X_test)

# %% [markdown]
# ## K-NN Evaluation

# %%
acc = accuracy_score(y_test, y_pred_nn)
print(acc)

show_conf_matrix(y_test, y_pred_nn, LABELS)
show_clf_report(y_test, y_pred_nn, LABELS)
# Out:
# 0.82607519610495
#               precision    recall  f1-score   support
#
#          sit       0.91      0.99      0.95      1360
#        sleep       0.97      0.96      0.96      1268
#        stand       0.65      1.00      0.79      2098
#         walk       1.00      0.55      0.71      2668
#
#    micro avg       0.83      0.83      0.83      7394
#    macro avg       0.88      0.87      0.85      7394
# weighted avg       0.88      0.83      0.82      7394

# %% [markdown]
# # Walk Algorithm

# %%
# %run classifier_alg.ipynb

# %%
# classify walking
walk = calc_walk(X_all)
walk_its = intersection_walk(walk)
walk_pred_p = calc_walk_periods(walk_its)

# walk_stairs_exact_p = get_exact_walk_stairs(y_all)
walk_exact_p = get_exact_walk(y_all)
    
walk_pred = binarize_walk_prd(walk_pred_p, y_all)
# walk_stairs_exact = binarize_walk_prd(walk_stairs_exact_p, y_all)
walk_exact = binarize_walk_prd(walk_exact_p, y_all)

# %% [markdown]
# ## Walk Algorithm Evaluation

# %%
walk_lbl = ['NaN','walk']

# %%
acc = accuracy_score(walk_exact, walk_pred)
print(acc)

show_conf_matrix(walk_exact, walk_pred, walk_lbl)
show_clf_report(walk_exact, walk_pred, walk_lbl)
# Out:
# 0.9217503309599628
#               precision    recall  f1-score   support
#
#          NaN       0.94      0.95      0.94     18941
#         walk       0.89      0.87      0.88      9008
#
#    micro avg       0.92      0.92      0.92     27949
#    macro avg       0.91      0.91      0.91     27949
# weighted avg       0.92      0.92      0.92     27949

# %% [markdown]
# # Combine SVM and Walk Algorithm

# %%
y_pred_new = combine(X_te, y_pred_svm)

# %%
acc = accuracy_score(y_te, y_pred_new)
print(acc)

show_conf_matrix(y_te, y_pred_new, LABELS)
show_clf_report(y_te, y_pred_new, LABELS)
# Out:
# 0.8673359627106489
#               precision    recall  f1-score   support
#
#          sit       0.82      0.84      0.83      1565
#        sleep       0.93      0.87      0.90      1534
#        stand       0.79      0.94      0.86      2351
#         walk       0.95      0.82      0.88      2917
#
#    micro avg       0.87      0.87      0.87      8367
#    macro avg       0.87      0.87      0.87      8367
# weighted avg       0.88      0.87      0.87      8367

# %% [markdown]
# # Test Model with Some Subject

# %%
test_subj = '2001'
filepath = 'DDC_Data/' + test_subj + '/' + test_subj + '-log_acc.csv'

df_test = pd.read_csv(filepath, header=None, names=['x','y','z','timestamp'])

# %%
ts_list = []
g = 9.8

for i in range(len(df_test)):
    X_i = [df_test.loc[i]['x']/g, df_test.loc[i]['y']/g, df_test.loc[i]['z']/g]
    ts_list.append(df_test.loc[i]['timestamp'])
    
    if(i==0):
        X_visua = X_i
    else:
        X_visua = np.vstack((X_visua, X_i))

ts_list = np.array(ts_list)

# %%
n_comp = 3

pca = PCA(n_components=n_comp)
pca = pca.fit(X_all)
X_vis_pca = pca.transform(X_visua)

# %%
X_vis_imp, ts_list_imp = prepare_impure_label(X_vis_pca, ts_list)

# %%
y_t_pred_ = svm_model.predict(X_vis_imp)
print("Finished prediction")
# Out:
# Finished prediction

# %%
y_t_pred = combine(X_vis_imp, y_t_pred_)

# %%
y_dict = {}
y_dict['timestamp'] = ts_list_imp
y_dict['y_pred'] = y_t_pred

df_y = pd.DataFrame(y_dict)

df_y['y_pred'].value_counts()
# Out:
# 2    8025
# 1    4362
# 0    3697
# 3    3333
# Name: y_pred, dtype: int64

# %% [markdown]
# # Get the Actual Timestamp Labels

# %%
timer_path = 'DDC_Data/' + test_subj + '/' + test_subj + '-iphone-history_amdtimer 6.csv'

cols = ['sid', 'timestamp', 'duration', 'label']
df_timer = pd.read_csv(timer_path, header=None, names=['sid','label','timestamp', 'duration'])
sid_list = np.array(list(df_timer['sid']))

tf = list(map(lambda x: x==int(test_subj), sid_list))
df_sid = df_timer[tf]
df_sid = df_sid.reset_index(drop=True)

# %% [markdown]
# # Group a Sequence into Periods by Labels

# %%
label_period = []
period_list = [[] for i in range(len(LABELS))]

first = 0
keep = 0

for i in range(len(df_y)):
    if(calc_sec(df_y.loc[i]['timestamp'].split(' ')[1])>=calc_sec(df_sid.loc[0]['timestamp'].split(' ')[1]) and
       calc_sec(df_y.loc[i]['timestamp'].split(' ')[1])<=calc_sec(df_sid.loc[len(df_sid)-1]['timestamp'].split(' ')[1])):
        
        keep_lb = df_y.loc[keep]['y_pred']

        if(keep_lb!=df_y.loc[i]['y_pred']):
            if(keep!=0):
                label_period.append([df_y.loc[keep]['timestamp'], df_y.loc[i-1]['timestamp'], 
                                     df_y.loc[i-1]['y_pred']])

                period_list[df_y.loc[i-1]['y_pred']].append([df_y.loc[keep]['timestamp'], df_y.loc[i-1]['timestamp']])

            keep = i

# %% [markdown]
# # Display Table

# %%
from prettytable import PrettyTable

# %%
labels_list = ['sit', 'sleep', 'stand', 'walk']
headers = ['start', 'end', 'label']

t = PrettyTable(headers)

for row in label_period:
#     if(calc_sec(row[1].split(' ')[1])-calc_sec(row[0].split(' ')[1])>1):
        t.add_row([row[0], row[1], labels_list[row[2]]])

# %%
print(t)
# Out:
# +-------------------------+-------------------------+-------+
# |          start          |           end           | label |
# +-------------------------+-------------------------+-------+
# | 2019-01-16 13:58:47.956 | 2019-01-16 13:59:27.309 | stand |
# | 2019-01-16 13:59:27.469 | 2019-01-16 14:00:01.525 |  sit  |
# | 2019-01-16 14:00:01.684 | 2019-01-16 14:00:43.281 | stand |
# | 2019-01-16 14:00:43.443 | 2019-01-16 14:00:44.405 |  walk |
# | 2019-01-16 14:00:44.566 | 2019-01-16 14:00:44.566 | stand |
# | 2019-01-16 14:00:44.726 | 2019-01-16 14:00:44.726 |  walk |
# | 2019-01-16 14:00:44.887 | 2019-01-16 14:00:44.887 | stand |
# | 2019-01-16 14:00:45.048 | 2019-01-16 14:00:45.369 |  walk |
# | 2019-01-16 14:00:45.532 | 2019-01-16 14:00:47.939 | stand |
# |  2019-01-16 14:00:48.1  |  2019-01-16 14:00:48.1  |  walk |
# | 2019-01-16 14:00:48.259 | 2019-01-16 14:00:48.422 | stand |
# | 2019-01-16 14:00:48.582 | 2019-01-16 14:00:48.582 |  walk |
# | 2019-01-16 14:00:48.743 | 2019-01-16 14:00:48.902 | stand |
# | 2019-01-16 14:00:49.062 | 2019-01-16 14:00:50.508 |  sit  |
# | 2019-01-16 14:00:50.668 | 2019-01-16 14:00:53.078 |  walk |
# |  2019-01-16 14:00:53.24 | 2019-01-16 14:00:53.401 | stand |
# | 2019-01-16 14:00:53.561 |  2019-01-16 14:00:53.88 |  walk |
# | 2019-01-16 14:00:54.043 | 2019-01-16 14:00:59.502 |  sit  |
# | 2019-01-16 14:00:59.662 | 2019-01-16 14:01:00.786 | stand |
# | 2019-01-16 14:01:00.947 | 2019-01-16 14:01:03.356 |  sit  |
# | 2019-01-16 14:01:03.517 | 2019-01-16 14:01:06.252 | sleep |
# |  2019-01-16 14:01:06.41 | 2019-01-16 14:01:07.213 |  sit  |
# | 2019-01-16 14:01:07.372 | 2019-01-16 14:01:08.819 | stand |
# | 2019-01-16 14:01:08.978 | 2019-01-16 14:01:23.114 |  sit  |
# | 2019-01-16 14:01:23.274 | 2019-01-16 14:02:04.719 | sleep |
# | 2019-01-16 14:02:04.879 | 2019-01-16 14:02:08.574 | stand |
# | 2019-01-16 14:02:08.735 | 2019-01-16 14:02:57.089 |  sit  |
# | 2019-01-16 14:02:57.252 | 2019-01-16 14:03:34.362 | sleep |
# | 2019-01-16 14:03:34.522 | 2019-01-16 14:04:42.155 | stand |
# | 2019-01-16 14:04:42.316 | 2019-01-16 14:04:42.316 |  walk |
# | 2019-01-16 14:04:42.476 | 2019-01-16 14:04:43.603 | stand |
# | 2019-01-16 14:04:43.764 | 2019-01-16 14:04:43.922 |  walk |
# | 2019-01-16 14:04:44.104 | 2019-01-16 14:04:45.208 | stand |
# | 2019-01-16 14:04:45.369 | 2019-01-16 14:04:45.529 |  walk |
# | 2019-01-16 14:04:45.692 | 2019-01-16 14:04:46.816 | stand |
# | 2019-01-16 14:04:46.976 | 2019-01-16 14:04:54.849 |  walk |
# | 2019-01-16 14:04:55.009 |  2019-01-16 14:04:55.17 | stand |
# | 2019-01-16 14:04:55.331 | 2019-01-16 14:04:56.455 |  walk |
# | 2019-01-16 14:04:56.617 | 2019-01-16 14:04:56.776 | stand |
# | 2019-01-16 14:04:56.937 | 2019-01-16 14:04:58.062 |  walk |
# | 2019-01-16 14:04:58.223 | 2019-01-16 14:04:58.384 | stand |
# | 2019-01-16 14:04:58.543 | 2019-01-16 14:04:59.668 |  walk |
# | 2019-01-16 14:04:59.829 | 2019-01-16 14:04:59.989 | stand |
# | 2019-01-16 14:05:00.152 | 2019-01-16 14:05:00.633 |  walk |
# | 2019-01-16 14:05:00.792 | 2019-01-16 14:05:00.792 | stand |
# | 2019-01-16 14:05:00.953 | 2019-01-16 14:05:01.274 |  walk |
# | 2019-01-16 14:05:01.435 | 2019-01-16 14:05:01.595 | stand |
# | 2019-01-16 14:05:01.756 | 2019-01-16 14:05:02.238 |  walk |
# | 2019-01-16 14:05:02.399 | 2019-01-16 14:05:02.399 | stand |
# |  2019-01-16 14:05:02.56 | 2019-01-16 14:05:02.882 |  walk |
# | 2019-01-16 14:05:03.041 | 2019-01-16 14:05:03.202 | stand |
# | 2019-01-16 14:05:03.365 | 2019-01-16 14:05:03.844 |  walk |
# | 2019-01-16 14:05:04.005 | 2019-01-16 14:05:04.166 | stand |
# | 2019-01-16 14:05:04.326 | 2019-01-16 14:05:04.487 |  walk |
# | 2019-01-16 14:05:04.648 | 2019-01-16 14:05:05.132 | stand |
# |  2019-01-16 14:05:05.29 | 2019-01-16 14:05:05.452 |  walk |
# | 2019-01-16 14:05:05.612 | 2019-01-16 14:05:05.774 | stand |
# | 2019-01-16 14:05:05.932 | 2019-01-16 14:05:06.094 |  walk |
# | 2019-01-16 14:05:06.255 | 2019-01-16 14:05:06.736 | stand |
# | 2019-01-16 14:05:06.897 | 2019-01-16 14:05:07.058 |  walk |
# |  2019-01-16 14:05:07.22 | 2019-01-16 14:05:07.379 | stand |
# | 2019-01-16 14:05:07.542 |  2019-01-16 14:05:07.7  |  walk |
# | 2019-01-16 14:05:07.863 | 2019-01-16 14:05:08.343 | stand |
# | 2019-01-16 14:05:08.503 | 2019-01-16 14:05:08.665 |  walk |
# | 2019-01-16 14:05:08.825 | 2019-01-16 14:05:08.985 | stand |
# | 2019-01-16 14:05:09.146 | 2019-01-16 14:05:09.308 |  walk |
# | 2019-01-16 14:05:09.467 | 2019-01-16 14:05:09.951 | stand |
# |  2019-01-16 14:05:10.11 | 2019-01-16 14:05:10.432 |  walk |
# | 2019-01-16 14:05:10.592 | 2019-01-16 14:05:10.592 | stand |
# | 2019-01-16 14:05:10.755 | 2019-01-16 14:05:10.914 |  walk |
# | 2019-01-16 14:05:11.074 | 2019-01-16 14:05:11.556 | stand |
# | 2019-01-16 14:05:11.717 | 2019-01-16 14:05:12.039 |  walk |
# | 2019-01-16 14:05:12.199 | 2019-01-16 14:05:12.199 | stand |
# | 2019-01-16 14:05:12.361 |  2019-01-16 14:05:12.52 |  walk |
# | 2019-01-16 14:05:12.682 | 2019-01-16 14:05:13.162 | stand |
# | 2019-01-16 14:05:13.322 | 2019-01-16 14:05:17.502 |  walk |
# | 2019-01-16 14:05:17.662 | 2019-01-16 14:05:18.142 | stand |
# | 2019-01-16 14:05:18.304 | 2019-01-16 14:05:19.106 |  walk |
# | 2019-01-16 14:05:19.267 |  2019-01-16 14:05:19.75 | stand |
# | 2019-01-16 14:05:19.909 | 2019-01-16 14:05:20.712 |  walk |
# | 2019-01-16 14:05:20.873 | 2019-01-16 14:05:21.355 | stand |
# | 2019-01-16 14:05:21.517 |  2019-01-16 14:05:22.32 |  walk |
# |  2019-01-16 14:05:22.48 | 2019-01-16 14:05:22.964 | stand |
# | 2019-01-16 14:05:23.122 | 2019-01-16 14:05:23.925 |  walk |
# | 2019-01-16 14:05:24.116 |  2019-01-16 14:05:24.57 | stand |
# | 2019-01-16 14:05:24.731 | 2019-01-16 14:05:25.533 |  walk |
# | 2019-01-16 14:05:25.693 | 2019-01-16 14:05:27.142 | stand |
# | 2019-01-16 14:05:27.302 | 2019-01-16 14:05:27.782 |  walk |
# | 2019-01-16 14:05:27.943 | 2019-01-16 14:05:28.747 | stand |
# | 2019-01-16 14:05:28.907 | 2019-01-16 14:05:29.389 |  walk |
# | 2019-01-16 14:05:29.552 | 2019-01-16 14:05:30.355 | stand |
# | 2019-01-16 14:05:30.514 | 2019-01-16 14:05:30.514 |  walk |
# | 2019-01-16 14:05:30.676 | 2019-01-16 14:05:31.962 | stand |
# |  2019-01-16 14:05:32.12 |  2019-01-16 14:05:32.12 |  walk |
# | 2019-01-16 14:05:32.281 | 2019-01-16 14:05:35.818 | stand |
# | 2019-01-16 14:05:35.978 |  2019-01-16 14:05:36.14 |  walk |
# | 2019-01-16 14:05:36.299 | 2019-01-16 14:05:36.299 | stand |
# | 2019-01-16 14:05:36.462 | 2019-01-16 14:05:36.462 |  walk |
# | 2019-01-16 14:05:36.622 | 2019-01-16 14:05:37.425 | stand |
# | 2019-01-16 14:05:37.585 | 2019-01-16 14:05:38.067 |  walk |
# | 2019-01-16 14:05:38.229 | 2019-01-16 14:05:43.047 | stand |
# | 2019-01-16 14:05:43.209 | 2019-01-16 14:05:43.209 |  walk |
# | 2019-01-16 14:05:43.369 | 2019-01-16 14:05:44.654 | stand |
# | 2019-01-16 14:05:44.816 | 2019-01-16 14:05:44.816 |  walk |
# | 2019-01-16 14:05:44.975 |  2019-01-16 14:05:46.26 | stand |
# | 2019-01-16 14:05:46.422 | 2019-01-16 14:05:46.422 |  walk |
# | 2019-01-16 14:05:46.583 | 2019-01-16 14:05:47.867 | stand |
# | 2019-01-16 14:05:48.027 | 2019-01-16 14:05:50.116 |  walk |
# | 2019-01-16 14:05:50.276 | 2019-01-16 14:05:51.561 | stand |
# | 2019-01-16 14:05:51.723 | 2019-01-16 14:05:51.723 |  walk |
# | 2019-01-16 14:05:51.884 | 2019-01-16 14:06:00.077 | stand |
# | 2019-01-16 14:06:00.237 | 2019-01-16 14:06:00.237 |  walk |
# | 2019-01-16 14:06:00.398 | 2019-01-16 14:06:11.324 | stand |
# | 2019-01-16 14:06:11.484 | 2019-01-16 14:06:11.644 |  walk |
# | 2019-01-16 14:06:11.805 | 2019-01-16 14:06:12.931 | stand |
# | 2019-01-16 14:06:13.091 | 2019-01-16 14:06:14.219 |  walk |
# | 2019-01-16 14:06:14.376 | 2019-01-16 14:07:15.747 | stand |
# | 2019-01-16 14:07:15.907 | 2019-01-16 14:07:21.531 |  walk |
# | 2019-01-16 14:07:21.691 | 2019-01-16 14:07:36.476 | stand |
# | 2019-01-16 14:07:36.637 | 2019-01-16 14:07:36.637 |  walk |
# | 2019-01-16 14:07:36.798 | 2019-01-16 14:07:38.083 | stand |
# | 2019-01-16 14:07:38.245 |  2019-01-16 14:07:39.53 |  walk |
# | 2019-01-16 14:07:39.692 | 2019-01-16 14:08:02.028 | stand |
# | 2019-01-16 14:08:02.189 | 2019-01-16 14:08:15.715 |  sit  |
# | 2019-01-16 14:08:15.876 | 2019-01-16 14:08:17.965 |  walk |
# | 2019-01-16 14:08:18.126 | 2019-01-16 14:08:23.592 | stand |
# |  2019-01-16 14:08:23.75 | 2019-01-16 14:08:26.163 |  sit  |
# | 2019-01-16 14:08:26.324 | 2019-01-16 14:08:27.125 | stand |
# | 2019-01-16 14:08:27.288 | 2019-01-16 14:08:36.447 |  sit  |
# | 2019-01-16 14:08:36.609 | 2019-01-16 14:08:36.768 |  walk |
# | 2019-01-16 14:08:36.929 | 2019-01-16 14:08:37.735 |  sit  |
# | 2019-01-16 14:08:37.895 | 2019-01-16 14:08:53.323 | stand |
# | 2019-01-16 14:08:53.485 | 2019-01-16 14:08:57.019 |  walk |
# | 2019-01-16 14:08:57.179 | 2019-01-16 14:08:57.179 | stand |
# | 2019-01-16 14:08:57.339 | 2019-01-16 14:08:58.624 |  walk |
# | 2019-01-16 14:08:58.787 | 2019-01-16 14:08:58.787 | stand |
# | 2019-01-16 14:08:58.946 | 2019-01-16 14:09:00.232 |  walk |
# | 2019-01-16 14:09:00.393 | 2019-01-16 14:09:00.393 | stand |
# | 2019-01-16 14:09:00.552 | 2019-01-16 14:09:01.838 |  walk |
# | 2019-01-16 14:09:01.998 | 2019-01-16 14:09:13.727 | stand |
# | 2019-01-16 14:09:13.887 | 2019-01-16 14:09:15.336 |  walk |
# | 2019-01-16 14:09:15.494 | 2019-01-16 14:09:15.978 | stand |
# | 2019-01-16 14:09:16.138 |  2019-01-16 14:09:16.94 |  walk |
# | 2019-01-16 14:09:17.101 | 2019-01-16 14:09:25.936 | stand |
# +-------------------------+-------------------------+-------+

# %%
df_sid[cols]
# Out:
#      sid                timestamp  duration       label
# 0   2001  2019-01-16 13:58:47.829  00:00:30       stand
# 1   2001  2019-01-16 13:59:26.627  00:00:30         sit
# 2   2001  2019-01-16 14:00:01.045  00:00:30       stand
# 3   2001  2019-01-16 14:01:30.673  00:00:30       sleep
# 4   2001  2019-01-16 14:02:09.519  00:00:30         sit
# 5   2001  2019-01-16 14:02:59.920  00:00:30       sleep
# 6   2001  2019-01-16 14:03:45.039  00:00:30       stand
# 7   2001  2019-01-16 14:04:32.327  00:00:31        walk
# 8   2001  2019-01-16 14:05:07.253  00:00:30        walk
# 9   2001  2019-01-16 14:07:04.700  00:00:43  downstairs
# 10  2001  2019-01-16 14:08:06.679  00:00:30    upstairs
# 11  2001  2019-01-16 14:08:44.824  00:00:37  downstairs
# 12  2001  2019-01-16 14:09:27.265  00:00:31    upstairs

# %% [markdown]
# # Predicted Duration

# %%
total_secs = []
for i in range(len(period_list)):    
    secs = 0
    for p_i in period_list[i]:
        sec = calc_sec(p_i[1].split(' ')[1]) - calc_sec(p_i[0].split(' ')[1])
        secs += sec
    
    secs = round(secs, 3)
    total_secs.append(secs)
    
percent_secs = [round(t/np.sum(total_secs)*100, 3) for t in total_secs]

tb = PrettyTable(['Label', 'Seconds', 'Percentage'])

for i in range(len(LABELS)):
    tb.add_row([labels_list[i], total_secs[i], percent_secs[i]])

tb.add_row(['', '', ''])
tb.add_row(['total', round(np.sum(total_secs), 3), round(np.sum(percent_secs), 3)])

# %%
print(tb)
# Out:
# +-------+---------+------------+
# | Label | Seconds | Percentage |
# +-------+---------+------------+
# |  sit  | 132.567 |   21.557   |
# | sleep |  81.29  |   13.219   |
# | stand | 349.376 |   56.813   |
# |  walk |  51.727 |   8.411    |
# |       |         |            |
# | total |  614.96 |   100.0    |
# +-------+---------+------------+

# %% [markdown]
# # Actual Duration

# %%
df_lb = df_sid.groupby('label')
old_labels_list = ['sit', 'sleep', 'downstairs', 'upstairs', 'stand', 'walk']

dura_dict = {}
for lb in labels_list:
    dura_dict[lb] = 0

idx = list(df_sid.index)
for i in range(len(old_labels_list)):
    lb = old_labels_list[i]
    df_temp = df_lb.get_group(lb)
    df_temp = df_temp.reset_index(drop=True)
        
    if(lb=='downstairs' or lb=='upstairs'):
        lb = 'walk'
    
    for j in range(len(df_temp)):
        dura_dict[lb] += calc_sec(df_temp.loc[j]['duration'])

total_dura = np.sum([dura_dict[lb] for lb in labels_list])

percent_list = []
        
tabl = PrettyTable(['Label', 'Seconds', 'Percentage'])
for lb in labels_list:
    percent = round(dura_dict[lb]/total_dura*100, 3)
    tabl.add_row([lb, dura_dict[lb], round(dura_dict[lb]/total_dura*100, 3)])
    
    percent_list.append(percent)
    
tabl.add_row(['', '', ''])    
tabl.add_row(['total', round(total_dura, 3), np.sum(percent_list)])

# %%
print(tabl)
# Out:
# +-------+---------+------------+
# | Label | Seconds | Percentage |
# +-------+---------+------------+
# |  sit  |   60.0  |   14.563   |
# | sleep |   60.0  |   14.563   |
# | stand |   90.0  |   21.845   |
# |  walk |  202.0  |   49.029   |
# |       |         |            |
# | total |  412.0  |   100.0    |
# +-------+---------+------------+

# %%
print('Prediction', 'Actual')
print (tb , tabl)
# Out:
# Prediction Actual
# +-------+---------+------------+
# | Label | Seconds | Percentage |
# +-------+---------+------------+
# |  sit  | 132.567 |   21.557   |
# | sleep |  81.29  |   13.219   |
# | stand | 349.376 |   56.813   |
# |  walk |  51.727 |   8.411    |
# |       |         |            |
# | total |  614.96 |   100.0    |
# +-------+---------+------------+ +-------+---------+------------+
# | Label | Seconds | Percentage |
# +-------+---------+------------+
# |  sit  |   60.0  |   14.563   |
# | sleep |   60.0  |   14.563   |
# | stand |   90.0  |   21.845   |
# |  walk |  202.0  |   49.029   |
# |       |         |            |
# | total |  412.0  |   100.0    |
# +-------+---------+------------+

# %% [markdown]
# # Bar Chart for Every 5 Minutes

# %%
s_idx = 0
f_idx = 1
lb_idx = 2

# %% [markdown]
# ## Separate Each 5 Minutes

# %%
fivemin = 60*5
new_label_period = []

start_time = calc_sec(label_period[0][s_idx].split(' ')[1])
finish_time = calc_sec(label_period[-1][f_idx].split(' ')[1])

floor_start = start_time - (start_time%fivemin)
ceil_finish = finish_time - (finish_time%fivemin) + fivemin

print(calc_ts(floor_start), calc_ts(ceil_finish))

tm_s = floor_start
tm_f = floor_start + fivemin
date = label_period[0][s_idx].split(' ')[0]

for prd in label_period:
    if(calc_sec(prd[f_idx].split(' ')[1])>=tm_f):
        new_prd = [prd[s_idx], date + ' ' + calc_ts(tm_f), prd[lb_idx]]
        new_label_period.append(new_prd)
        
        tm_s += fivemin
        tm_f += fivemin
    else:
        new_label_period.append(prd)
                
    if(calc_sec(prd[s_idx].split(' ')[1])<tm_s):
        new_prd = [date + ' ' + calc_ts(tm_s), prd[f_idx], prd[lb_idx]]
        new_label_period.append(new_prd)
# Out:
# 13:55:0.0 14:10:0.0

# %%
all_periods_label = []

for t_i in range(int(floor_start), int(ceil_finish), t_5min):
    period_lb = [0 for i in range(len(LABELS))]
    for prd in new_label_period:
        if(calc_sec(prd[s_idx].split(' ')[1])>=t_i and calc_sec(prd[f_idx].split(' ')[1])<=t_i+t_5min):
            period_lb[prd[lb_idx]] += calc_sec(prd[f_idx].split(' ')[1])-calc_sec(prd[s_idx].split(' ')[1])
            period_lb[prd[lb_idx]] = round(period_lb[prd[lb_idx]], 3)
            
    all_periods_label.append(period_lb)

# %%
df_all = pd.DataFrame(all_periods_label, columns=labels_list)

df_all
# Out:
#       sit  sleep    stand    walk
# 0  32.531   0.00   39.353   0.000
# 1  74.132  81.29  122.382  15.425
# 2  25.904   0.00  187.641  35.517

# %% [markdown]
# ## Plot Bar Graph

# %%
pos = list(range(len(df_all['sit'])))
width = 0.2
colors = ['crimson','gold','lime','dodgerblue']

fig, ax = plt.subplots(figsize=(10,5))

for i in range(len(LABELS)):
    plt.bar([p + i*width for p in pos],
            df_all[labels_list[i]],
            width,
            alpha=0.5,
            color=colors[i],
            label=labels_list[i])
    
ax.set_xticks([p + 1.5 * width for p in pos])

xtick_labels = [calc_ts(floor_start + i*fivemin) + '-' + calc_ts(floor_start + (i+1)*fivemin)
                for i in range(len(df_all))]
ax.set_xticklabels(xtick_labels)

ax.set_ylabel('Time (sec)')

plt.xlim(min(pos)-width, max(pos)+width*4)
plt.legend(loc='upper left')
plt.title('Activity Summary for Subject ID: ' + test_subj)

plt.show()

# %%
print('Prediction')
print (tb)
print('Actual')
print (tabl)
# Out:
# Prediction
# +-------+---------+------------+
# | Label | Seconds | Percentage |
# +-------+---------+------------+
# |  sit  | 132.567 |   21.557   |
# | sleep |  81.29  |   13.219   |
# | stand | 349.376 |   56.813   |
# |  walk |  51.727 |   8.411    |
# |       |         |            |
# | total |  614.96 |   100.0    |
# +-------+---------+------------+
# Actual
# +-------+---------+------------+
# | Label | Seconds | Percentage |
# +-------+---------+------------+
# |  sit  |   60.0  |   14.563   |
# | sleep |   60.0  |   14.563   |
# | stand |   90.0  |   21.845   |
# |  walk |  202.0  |   49.029   |
# |       |         |            |
# | total |  412.0  |   100.0    |
# +-------+---------+------------+
