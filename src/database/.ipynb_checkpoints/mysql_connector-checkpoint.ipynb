# %% [markdown]
# # Import Libraries

# %%
import mysql.connector

# %%
import pickle
import ruptures as rpt
import sklearn

from prettytable import PrettyTable

# %% [markdown]
# # Connect to MySQL Database

# %%
mydb = mysql.connector.connect(
    host='localhost',
    user='root',
    passwd='slow675',
    database='amd_project'
    )

# %%
print(mydb)
# Out:
# <mysql.connector.connection.MySQLConnection object at 0x1c0dd58a90>

# %%
mycursor = mydb.cursor()

# %% [markdown]
# # Load Dataset

# %%
# %run data_cleanse.ipynb
# Out:
# Loading 2001's data
# Loading 3001's data
# Loading 3002's data
# Loading 3003's data
# Loading 3004's data
# Loading 3005's data
# Finished Loading

# %% [markdown]
# # Predict Labels

# %%
# %run predict.ipynb

# %% [markdown]
# # Analyze Predicted Results

# %%
# %run summarize.ipynb

# %%
df_all_p_sorted
# Out:
#        Unnamed: 0    ID                timestamp         x         y  \
# 0               0  2001  2019-01-16 13:58:47.956  0.246041  0.475436
# 1               1  2001  2019-01-16 13:58:48.117  0.246431  0.473881
# 2               2  2001  2019-01-16 13:58:48.278  0.246236  0.474464
# 3               3  2001  2019-01-16 13:58:48.439  0.246041  0.473881
# 4               4  2001    2019-01-16 13:58:48.6  0.246821  0.472521
# 5               5  2001   2019-01-16 13:58:48.76  0.247016  0.474659
# 6               6  2001  2019-01-16 13:58:48.922  0.247211  0.477574
# 7               7  2001   2019-01-16 13:58:49.08  0.245262  0.469994
# 8               8  2001  2019-01-16 13:58:49.243  0.246041  0.475047
# 9               9  2001  2019-01-16 13:58:49.402  0.246236  0.471937
# 10             10  2001  2019-01-16 13:58:49.562  0.246041  0.473492
# 11             11  2001  2019-01-16 13:58:49.723  0.242144  0.472326
# 12             12  2001  2019-01-16 13:58:49.884  0.245457  0.472132
# 13             13  2001  2019-01-16 13:58:50.045  0.246236  0.475047
# 14             14  2001  2019-01-16 13:58:50.205  0.243703  0.477185
# 15             15  2001  2019-01-16 13:58:50.366  0.244677  0.477963
# 16             16  2001  2019-01-16 13:58:50.526  0.245067  0.475436
# 17             17  2001  2019-01-16 13:58:50.687  0.245262  0.483211
# 18             18  2001  2019-01-16 13:58:50.848  0.247016  0.473492
# 19             19  2001  2019-01-16 13:58:51.009  0.244482  0.471743
# 20             20  2001  2019-01-16 13:58:51.169  0.244482  0.470966
# 21             21  2001  2019-01-16 13:58:51.332  0.244872  0.472715
# 22             22  2001   2019-01-16 13:58:51.49  0.247406  0.473492
# 23             23  2001  2019-01-16 13:58:51.651  0.245652  0.472326
# 24             24  2001  2019-01-16 13:58:51.812  0.246626  0.473881
# 25             25  2001  2019-01-16 13:58:51.972  0.245067  0.474076
# 26             26  2001  2019-01-16 13:58:52.134  0.244677  0.470382
# 27             27  2001  2019-01-16 13:58:52.294  0.243703  0.475825
# 28             28  2001  2019-01-16 13:58:52.454  0.242923  0.470188
# 29             29  2001  2019-01-16 13:58:52.615  0.244872  0.479518
# ...           ...   ...                      ...       ...       ...
# 16548       16548  3005  2019-03-05 13:05:52.444  0.765662  0.479994
# 16549       16549  3005  2019-03-05 13:05:52.605  0.714778  0.467301
# 16550       16550  3005  2019-03-05 13:05:52.766  0.762793  0.439432
# 16551       16551  3005  2019-03-05 13:05:52.928  0.653754  0.412941
# 16552       16552  3005  2019-03-05 13:05:53.087  0.839885  0.377070
# 16553       16553  3005  2019-03-05 13:05:53.249  0.860545  0.404939
# 16554       16554  3005  2019-03-05 13:05:53.409  0.712865  0.466198
# 16555       16555  3005  2019-03-05 13:05:53.568  0.755141  0.535458
# 16556       16556  3005   2019-03-05 13:05:53.73  0.779627  0.487997
# 16557       16557  3005  2019-03-05 13:05:53.889  0.741176  0.399696
# 16558       16558  3005  2019-03-05 13:05:54.051  0.656815  0.404111
# 16559       16559  3005  2019-03-05 13:05:54.211  0.785748  0.424531
# 16560       16560  3005  2019-03-05 13:05:54.372  0.934577  0.481374
# 16561       16561  3005  2019-03-05 13:05:54.532  0.682257  0.503449
# 16562       16562  3005  2019-03-05 13:05:54.692  0.762984  0.548427
# 16563       16563  3005  2019-03-05 13:05:54.854  0.773505  0.475028
# 16564       16564  3005  2019-03-05 13:05:55.014  0.787853  0.499586
# 16565       16565  3005  2019-03-05 13:05:55.175  0.663319  0.471440
# 16566       16566  3005  2019-03-05 13:05:55.335  0.695265  0.458471
# 16567       16567  3005  2019-03-05 13:05:55.496  0.701961  0.483858
# 16568       16568  3005  2019-03-05 13:05:55.657  0.710187  0.529939
# 16569       16569  3005  2019-03-05 13:05:55.818  0.723003  0.516418
# 16570       16570  3005  2019-03-05 13:05:55.978  0.936490  0.537666
# 16571       16571  3005  2019-03-05 13:05:56.137  0.817121  0.506760
# 16572       16572  3005  2019-03-05 13:05:56.302  0.689144  0.430877
# 16573       16573  3005  2019-03-05 13:05:56.459  0.715352  0.433637
# 16574       16574  3005  2019-03-05 13:05:56.621  0.920995  0.515039
# 16575       16575  3005  2019-03-05 13:05:56.781  0.835103  0.460955
# 16576       16576  3005  2019-03-05 13:05:56.941  0.726447  0.516970
# 16577       16577  3005  2019-03-05 13:05:57.101  0.774462  0.524972
#
#               z         HR  y_pred
# 0      0.576183  68.205284       2
# 1      0.576429  68.205284       2
# 2      0.573722  68.205284       2
# 3      0.574460  67.365480       2
# 4      0.575444  67.365480       2
# 5      0.572246  67.365480       2
# 6      0.573722  67.365480       2
# 7      0.575198  67.365480       2
# 8      0.571754  67.365480       2
# 9      0.570277  67.365480       2
# 10     0.571508  66.945570       2
# 11     0.572984  66.945570       2
# 12     0.570770  66.945570       2
# 13     0.570277  66.945570       2
# 14     0.573968  66.945570       2
# 15     0.567817  66.945570       2
# 16     0.573476  66.945570       2
# 17     0.566341  66.891680       2
# 18     0.572000  66.891680       2
# 19     0.572738  66.891680       2
# 20     0.573968  66.891680       2
# 21     0.570523  66.891680       2
# 22     0.569785  66.891680       2
# 23     0.574214  66.891680       2
# 24     0.567817  66.883880       2
# 25     0.570770  66.883880       2
# 26     0.572246  66.883880       2
# 27     0.572492  66.883880       2
# 28     0.574460  66.883880       2
# 29     0.571262  66.883880       2
# ...         ...        ...     ...
# 16548  0.751300  85.435660       3
# 16549  0.768947  85.435660       3
# 16550  0.640416  85.435660       3
# 16551  0.620136  85.435660       3
# 16552  0.647001  85.435660       3
# 16553  0.722592  85.435660       3
# 16554  0.723645  83.078640       3
# 16555  0.802924  83.078640       3
# 16556  0.693093  83.078640       3
# 16557  0.570356  83.078640       3
# 16558  0.612234  83.078640       3
# 16559  0.616448  83.078640       3
# 16560  0.745769  83.078640       3
# 16561  0.683874  80.898530       3
# 16562  0.681241  80.898530       3
# 16563  0.652005  80.898530       3
# 16564  0.558504  80.898530       3
# 16565  0.585632  80.898530       3
# 16566  0.645420  80.898530       3
# 16567  0.701521  80.898530       3
# 16568  0.666754  68.207535       3
# 16569  0.678607  68.207535       3
# 16570  0.617502  68.207535       3
# 16571  0.591427  68.207535       3
# 16572  0.584842  68.207535       3
# 16573  0.600909  68.207535       3
# 16574  0.654902  68.207535       3
# 16575  0.671495  68.207535       3
# 16576  0.653059  68.207535       3
# 16577  0.650161  68.207535       3
#
# [16578 rows x 8 columns]

# %% [markdown]
# # Insert to Database

# %%
sql = "INSERT INTO Patient (ID, Dateandtime, X, Y, Z, HR, Label) \
    VALUES (%s, %s, %s, %s, %s, %s, %s)"

for row in zip(df_all_p_sorted['ID'], 
               df_all_p_sorted['timestamp'], 
               df_all_p_sorted['x'], 
               df_all_p_sorted['y'], 
               df_all_p_sorted['z'], 
               df_all_p_sorted['HR'], 
               df_all_p_sorted['y_pred']):
    
    mycursor.execute(sql, row)

mydb.commit()

# %%
sql = "INSERT INTO AllDaySummary (ID, Date, TimeFrom, TimeUntil,\
    DurationSit, DurationSleep, DurationStand, DurationWalk,\
    CountSit, CountSleep, CountStand, CountWalk,\
    CountActive, CountInactive,\
    CountTotalActiveness, CountTransition, DurationPerTransition)\
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s,\
    # %s, %s, %s, %s, %s, %s, %s, %s)"

for row in zip(df_summary_all['ID'], 
               df_summary_all['date'], 
               df_summary_all['from'],
               df_summary_all['to'], 
               df_summary_all['sit'], 
               df_summary_all['sleep'], 
               df_summary_all['stand'],
               df_summary_all['walk'],
               df_summary_all['sit count'], 
               df_summary_all['sleep count'], 
               df_summary_all['stand count'], 
               df_summary_all['walk count'], 
               df_summary_all['inactive count'], 
               df_summary_all['active count'], 
               df_summary_all['total count'], 
               df_summary_all['transition count'], 
               df_summary_all['duration per action']):
    
    mycursor.execute(sql, row)
    
mydb.commit()

# %%
sql = "INSERT INTO ActivityPeriod (ID, Date, TimeFrom, TimeUntil, Label)\
    VALUES (%s, %s, %s, %s, %s)"

for row in zip(df_act_period['ID'], 
               df_act_period['date'], 
               df_act_period['from'],
               df_act_period['to'],
               df_act_period['y_pred']):
    
    mycursor.execute(sql, row)

mydb.commit()

# %% [markdown]
# # Show Results

# %%
mycursor.execute("SELECT * FROM Patient")

myresult = mycursor.fetchall()

print(len(myresult))

for x in range(50):
    print(myresult[x])
# Out:
# 16578
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 47, 956000), 0.246, 0.4754, 0.5762, 68.2053, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 48, 117000), 0.2464, 0.4739, 0.5764, 68.2053, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 48, 278000), 0.2462, 0.4745, 0.5737, 68.2053, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 48, 439000), 0.246, 0.4739, 0.5745, 67.3655, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 48, 600000), 0.2468, 0.4725, 0.5754, 67.3655, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 48, 760000), 0.247, 0.4747, 0.5722, 67.3655, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 48, 922000), 0.2472, 0.4776, 0.5737, 67.3655, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 49, 80000), 0.2453, 0.47, 0.5752, 67.3655, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 49, 243000), 0.246, 0.475, 0.5718, 67.3655, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 49, 402000), 0.2462, 0.4719, 0.5703, 67.3655, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 49, 562000), 0.246, 0.4735, 0.5715, 66.9456, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 49, 723000), 0.2421, 0.4723, 0.573, 66.9456, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 49, 884000), 0.2455, 0.4721, 0.5708, 66.9456, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 50, 45000), 0.2462, 0.475, 0.5703, 66.9456, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 50, 205000), 0.2437, 0.4772, 0.574, 66.9456, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 50, 366000), 0.2447, 0.478, 0.5678, 66.9456, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 50, 526000), 0.2451, 0.4754, 0.5735, 66.9456, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 50, 687000), 0.2453, 0.4832, 0.5663, 66.8917, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 50, 848000), 0.247, 0.4735, 0.572, 66.8917, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 51, 9000), 0.2445, 0.4717, 0.5727, 66.8917, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 51, 169000), 0.2445, 0.471, 0.574, 66.8917, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 51, 332000), 0.2449, 0.4727, 0.5705, 66.8917, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 51, 490000), 0.2474, 0.4735, 0.5698, 66.8917, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 51, 651000), 0.2457, 0.4723, 0.5742, 66.8917, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 51, 812000), 0.2466, 0.4739, 0.5678, 66.8839, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 51, 972000), 0.2451, 0.4741, 0.5708, 66.8839, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 52, 134000), 0.2447, 0.4704, 0.5722, 66.8839, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 52, 294000), 0.2437, 0.4758, 0.5725, 66.8839, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 52, 454000), 0.2429, 0.4702, 0.5745, 66.8839, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 52, 615000), 0.2449, 0.4795, 0.5713, 66.8839, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 52, 775000), 0.2453, 0.4745, 0.5745, 66.8839, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 52, 936000), 0.2468, 0.4782, 0.5752, 67.4191, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 53, 97000), 0.2451, 0.4807, 0.5767, 67.4191, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 53, 259000), 0.2453, 0.4764, 0.5705, 67.4191, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 53, 418000), 0.2462, 0.4764, 0.571, 67.4191, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 53, 580000), 0.2443, 0.4784, 0.5757, 67.4191, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 53, 739000), 0.246, 0.4764, 0.5698, 67.4191, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 53, 902000), 0.2439, 0.4766, 0.57, 67.4191, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 54, 80000), 0.2453, 0.4743, 0.5725, 67.6867, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 54, 222000), 0.2464, 0.4743, 0.5678, 67.6867, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 54, 382000), 0.2449, 0.4747, 0.57, 67.6867, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 54, 542000), 0.2439, 0.4749, 0.5683, 67.6867, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 54, 703000), 0.2443, 0.4719, 0.5722, 67.6867, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 54, 864000), 0.2472, 0.4745, 0.5715, 67.6867, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 55, 29000), 0.247, 0.476, 0.5722, 67.8205, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 55, 185000), 0.2468, 0.4737, 0.575, 67.8205, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 55, 345000), 0.2484, 0.4684, 0.5713, 67.8205, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 55, 506000), 0.2451, 0.4789, 0.5737, 67.8205, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 55, 668000), 0.249, 0.4688, 0.5678, 67.8205, 2)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 55, 828000), 0.2492, 0.4696, 0.571, 67.8205, 2)

# %%
mycursor.execute("SELECT * FROM ActivityPeriod")

myresult = mycursor.fetchall()

print(len(myresult))

for x in range(len(myresult)):
    print(myresult[x])
# Out:
# 1010
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50327), datetime.timedelta(0, 50362), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50362), datetime.timedelta(0, 50398), 0)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50398), datetime.timedelta(0, 50400), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50400), datetime.timedelta(0, 50436), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50436), datetime.timedelta(0, 50438), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50438), datetime.timedelta(0, 50443), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50443), datetime.timedelta(0, 50443), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50444), datetime.timedelta(0, 50444), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50444), datetime.timedelta(0, 50446), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50444), datetime.timedelta(0, 50444), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50447), datetime.timedelta(0, 50454), 0)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50447), datetime.timedelta(0, 50447), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50447), datetime.timedelta(0, 50447), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50454), datetime.timedelta(0, 50461), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50461), datetime.timedelta(0, 50462), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50462), datetime.timedelta(0, 50463), 0)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50464), datetime.timedelta(0, 50467), 1)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50467), datetime.timedelta(0, 50469), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50469), datetime.timedelta(0, 50473), 0)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50473), datetime.timedelta(0, 50474), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50474), datetime.timedelta(0, 50481), 0)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50481), datetime.timedelta(0, 50482), 1)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50482), datetime.timedelta(0, 50482), 0)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50483), datetime.timedelta(0, 50486), 0)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50483), datetime.timedelta(0, 50483), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50486), datetime.timedelta(0, 50487), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50487), datetime.timedelta(0, 50493), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50493), datetime.timedelta(0, 50493), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50494), datetime.timedelta(0, 50524), 1)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50524), datetime.timedelta(0, 50526), 0)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50527), datetime.timedelta(0, 50528), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50529), datetime.timedelta(0, 50533), 0)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50533), datetime.timedelta(0, 50535), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50535), datetime.timedelta(0, 50564), 0)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50564), datetime.timedelta(0, 50565), 1)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50565), datetime.timedelta(0, 50568), 0)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50568), datetime.timedelta(0, 50570), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50570), datetime.timedelta(0, 50571), 1)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50571), datetime.timedelta(0, 50579), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50580), datetime.timedelta(0, 50614), 1)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50614), datetime.timedelta(0, 50622), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50622), datetime.timedelta(0, 50627), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50622), datetime.timedelta(0, 50622), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50627), datetime.timedelta(0, 50627), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50627), datetime.timedelta(0, 50627), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50627), datetime.timedelta(0, 50627), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50628), datetime.timedelta(0, 50628), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50628), datetime.timedelta(0, 50629), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50629), datetime.timedelta(0, 50630), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50630), datetime.timedelta(0, 50655), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50630), datetime.timedelta(0, 50630), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50655), datetime.timedelta(0, 50656), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50656), datetime.timedelta(0, 50656), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50656), datetime.timedelta(0, 50659), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50660), datetime.timedelta(0, 50660), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50660), datetime.timedelta(0, 50660), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50660), datetime.timedelta(0, 50660), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50660), datetime.timedelta(0, 50661), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50661), datetime.timedelta(0, 50661), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50661), datetime.timedelta(0, 50663), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50661), datetime.timedelta(0, 50661), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50663), datetime.timedelta(0, 50674), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50663), datetime.timedelta(0, 50663), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50674), datetime.timedelta(0, 50675), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50675), datetime.timedelta(0, 50676), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50676), datetime.timedelta(0, 50677), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50676), datetime.timedelta(0, 50676), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50677), datetime.timedelta(0, 50679), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50677), datetime.timedelta(0, 50677), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50679), datetime.timedelta(0, 50679), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50679), datetime.timedelta(0, 50679), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50679), datetime.timedelta(0, 50706), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50706), datetime.timedelta(0, 50706), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50706), datetime.timedelta(0, 50708), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50708), datetime.timedelta(0, 50708), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50708), datetime.timedelta(0, 50708), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50709), datetime.timedelta(0, 50709), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50709), datetime.timedelta(0, 50732), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50732), datetime.timedelta(0, 50732), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50732), datetime.timedelta(0, 50734), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50734), datetime.timedelta(0, 50734), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50734), datetime.timedelta(0, 50734), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50734), datetime.timedelta(0, 50734), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50735), datetime.timedelta(0, 50735), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50735), datetime.timedelta(0, 50735), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50735), datetime.timedelta(0, 50738), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50739), datetime.timedelta(0, 50739), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50739), datetime.timedelta(0, 50740), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50740), datetime.timedelta(0, 50741), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50741), datetime.timedelta(0, 50741), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50741), datetime.timedelta(0, 50741), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50741), datetime.timedelta(0, 50741), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50742), datetime.timedelta(0, 50742), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50743), datetime.timedelta(0, 50743), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50743), datetime.timedelta(0, 50743), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50743), datetime.timedelta(0, 50744), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50744), datetime.timedelta(0, 50755), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50755), datetime.timedelta(0, 50756), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50756), datetime.timedelta(0, 50758), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50758), datetime.timedelta(0, 50759), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50758), datetime.timedelta(0, 50758), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50759), datetime.timedelta(0, 50833), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50759), datetime.timedelta(0, 50759), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50834), datetime.timedelta(0, 50834), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50834), datetime.timedelta(0, 50834), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50834), datetime.timedelta(0, 50834), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50834), datetime.timedelta(0, 50834), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50834), datetime.timedelta(0, 50846), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50846), datetime.timedelta(0, 50846), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50846), datetime.timedelta(0, 50846), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50847), datetime.timedelta(0, 50847), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50847), datetime.timedelta(0, 50848), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50848), datetime.timedelta(0, 50849), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50850), datetime.timedelta(0, 50850), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50850), datetime.timedelta(0, 50850), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50850), datetime.timedelta(0, 50850), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50850), datetime.timedelta(0, 50850), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50851), datetime.timedelta(0, 50851), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50851), datetime.timedelta(0, 50851), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50851), datetime.timedelta(0, 50851), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50851), datetime.timedelta(0, 50851), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50851), datetime.timedelta(0, 50851), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50851), datetime.timedelta(0, 50851), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50851), datetime.timedelta(0, 50863), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50863), datetime.timedelta(0, 50866), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50866), datetime.timedelta(0, 50866), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50866), datetime.timedelta(0, 50866), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50867), datetime.timedelta(0, 50868), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50868), datetime.timedelta(0, 50868), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50869), datetime.timedelta(0, 50869), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50869), datetime.timedelta(0, 50872), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50869), datetime.timedelta(0, 50869), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50869), datetime.timedelta(0, 50869), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50872), datetime.timedelta(0, 50873), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50873), datetime.timedelta(0, 50873), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50873), datetime.timedelta(0, 50873), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50873), datetime.timedelta(0, 50873), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50873), datetime.timedelta(0, 50873), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50874), datetime.timedelta(0, 50874), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50874), datetime.timedelta(0, 50875), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50876), datetime.timedelta(0, 50881), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50881), datetime.timedelta(0, 50882), 0)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50882), datetime.timedelta(0, 50895), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50895), datetime.timedelta(0, 50896), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50896), datetime.timedelta(0, 50901), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50902), datetime.timedelta(0, 50902), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50902), datetime.timedelta(0, 50906), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50906), datetime.timedelta(0, 50908), 0)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50908), datetime.timedelta(0, 50923), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50923), datetime.timedelta(0, 50934), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50934), datetime.timedelta(0, 50934), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50934), datetime.timedelta(0, 50934), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50934), datetime.timedelta(0, 50934), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50934), datetime.timedelta(0, 50934), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50935), datetime.timedelta(0, 50935), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50935), datetime.timedelta(0, 50935), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50935), datetime.timedelta(0, 50936), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50936), datetime.timedelta(0, 50936), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50936), datetime.timedelta(0, 50936), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50937), datetime.timedelta(0, 50937), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50937), datetime.timedelta(0, 50937), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50937), datetime.timedelta(0, 50938), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50937), datetime.timedelta(0, 50937), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50937), datetime.timedelta(0, 50937), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50938), datetime.timedelta(0, 50939), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50939), datetime.timedelta(0, 50939), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50939), datetime.timedelta(0, 50940), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50939), datetime.timedelta(0, 50939), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50940), datetime.timedelta(0, 50941), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50941), datetime.timedelta(0, 50941), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50941), datetime.timedelta(0, 50941), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50941), datetime.timedelta(0, 50941), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50941), datetime.timedelta(0, 50942), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50942), datetime.timedelta(0, 50945), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50945), datetime.timedelta(0, 50945), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50946), datetime.timedelta(0, 50946), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50946), datetime.timedelta(0, 50947), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50946), datetime.timedelta(0, 50946), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50947), datetime.timedelta(0, 50947), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50947), datetime.timedelta(0, 50947), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50948), datetime.timedelta(0, 50948), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50948), datetime.timedelta(0, 50948), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50949), datetime.timedelta(0, 50949), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50949), datetime.timedelta(0, 50949), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50949), datetime.timedelta(0, 50956), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50956), datetime.timedelta(0, 50956), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50956), datetime.timedelta(0, 50958), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50958), datetime.timedelta(0, 50958), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50958), datetime.timedelta(0, 50959), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50959), datetime.timedelta(0, 50964), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50964), datetime.timedelta(0, 50966), 0)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50966), datetime.timedelta(0, 50973), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50973), datetime.timedelta(0, 50973), 0)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50973), datetime.timedelta(0, 50975), 0)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50973), datetime.timedelta(0, 50973), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50975), datetime.timedelta(0, 50976), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50975), datetime.timedelta(0, 50975), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50976), datetime.timedelta(0, 50980), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50981), datetime.timedelta(0, 50981), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50981), datetime.timedelta(0, 50983), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50983), datetime.timedelta(0, 50984), 2)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50984), datetime.timedelta(0, 50993), 3)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50993), datetime.timedelta(0, 50993), 0)
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50993), datetime.timedelta(0, 50998), 3)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36204), datetime.timedelta(0, 36246), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36246), datetime.timedelta(0, 36288), 0)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36289), datetime.timedelta(0, 36328), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36329), datetime.timedelta(0, 36329), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36329), datetime.timedelta(0, 36338), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36329), datetime.timedelta(0, 36329), 3)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36329), datetime.timedelta(0, 36329), 3)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36338), datetime.timedelta(0, 36347), 0)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36347), datetime.timedelta(0, 36350), 1)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36350), datetime.timedelta(0, 36354), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36354), datetime.timedelta(0, 36355), 3)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36355), datetime.timedelta(0, 36355), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36355), datetime.timedelta(0, 36355), 3)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36356), datetime.timedelta(0, 36358), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36358), datetime.timedelta(0, 36358), 1)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36359), datetime.timedelta(0, 36387), 1)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36359), datetime.timedelta(0, 36359), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36387), datetime.timedelta(0, 36395), 0)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36395), datetime.timedelta(0, 36396), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36396), datetime.timedelta(0, 36436), 0)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36436), datetime.timedelta(0, 36471), 1)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36471), datetime.timedelta(0, 36474), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36474), datetime.timedelta(0, 36474), 0)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36474), datetime.timedelta(0, 36476), 1)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36476), datetime.timedelta(0, 36482), 0)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36482), datetime.timedelta(0, 36488), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36488), datetime.timedelta(0, 36488), 0)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36488), datetime.timedelta(0, 36492), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36492), datetime.timedelta(0, 36492), 0)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36492), datetime.timedelta(0, 36492), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36493), datetime.timedelta(0, 36493), 0)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36493), datetime.timedelta(0, 36499), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36499), datetime.timedelta(0, 36499), 3)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36500), datetime.timedelta(0, 36500), 1)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36500), datetime.timedelta(0, 36503), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36503), datetime.timedelta(0, 36503), 1)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36503), datetime.timedelta(0, 36503), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36504), datetime.timedelta(0, 36507), 3)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36507), datetime.timedelta(0, 36544), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36544), datetime.timedelta(0, 36545), 3)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36545), datetime.timedelta(0, 36545), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36545), datetime.timedelta(0, 36545), 3)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36546), datetime.timedelta(0, 36549), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36549), datetime.timedelta(0, 36557), 0)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36557), datetime.timedelta(0, 36558), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36559), datetime.timedelta(0, 36559), 0)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36559), datetime.timedelta(0, 36562), 0)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36559), datetime.timedelta(0, 36559), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36562), datetime.timedelta(0, 36570), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36571), datetime.timedelta(0, 36582), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36571), datetime.timedelta(0, 36571), 3)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36582), datetime.timedelta(0, 36583), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36582), datetime.timedelta(0, 36582), 3)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36583), datetime.timedelta(0, 36583), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36583), datetime.timedelta(0, 36583), 3)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36584), datetime.timedelta(0, 36584), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36584), datetime.timedelta(0, 36584), 3)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36584), datetime.timedelta(0, 36584), 3)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36585), datetime.timedelta(0, 36586), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36587), datetime.timedelta(0, 36587), 3)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36588), datetime.timedelta(0, 36588), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36588), datetime.timedelta(0, 36588), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36588), datetime.timedelta(0, 36588), 3)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36588), datetime.timedelta(0, 36640), 3)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36640), datetime.timedelta(0, 36640), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36640), datetime.timedelta(0, 36646), 3)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36646), datetime.timedelta(0, 36646), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36647), datetime.timedelta(0, 36647), 1)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36647), datetime.timedelta(0, 36647), 2)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36647), datetime.timedelta(0, 36647), 3)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36647), datetime.timedelta(0, 36647), 3)
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36648), datetime.timedelta(0, 36648), 1)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44617), datetime.timedelta(0, 44647), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44648), datetime.timedelta(0, 44648), 0)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44648), datetime.timedelta(0, 44649), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44649), datetime.timedelta(0, 44684), 0)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44684), datetime.timedelta(0, 44721), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44721), datetime.timedelta(0, 44723), 3)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44723), datetime.timedelta(0, 44725), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44726), datetime.timedelta(0, 44726), 0)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44726), datetime.timedelta(0, 44726), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44727), datetime.timedelta(0, 44729), 0)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44729), datetime.timedelta(0, 44730), 1)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44731), datetime.timedelta(0, 44732), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44733), datetime.timedelta(0, 44766), 1)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44766), datetime.timedelta(0, 44768), 0)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44768), datetime.timedelta(0, 44772), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44772), datetime.timedelta(0, 44773), 1)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44773), datetime.timedelta(0, 44774), 3)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44774), datetime.timedelta(0, 44803), 0)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44803), datetime.timedelta(0, 44838), 1)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44838), datetime.timedelta(0, 44883), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44883), datetime.timedelta(0, 44884), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44883), datetime.timedelta(0, 44883), 3)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44884), datetime.timedelta(0, 44888), 3)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44888), datetime.timedelta(0, 44892), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44892), datetime.timedelta(0, 44893), 3)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44893), datetime.timedelta(0, 44896), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44896), datetime.timedelta(0, 44900), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44896), datetime.timedelta(0, 44896), 3)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44900), datetime.timedelta(0, 44902), 3)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44902), datetime.timedelta(0, 44909), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44909), datetime.timedelta(0, 44928), 3)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44928), datetime.timedelta(0, 44930), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44930), datetime.timedelta(0, 44930), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44930), datetime.timedelta(0, 44941), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44930), datetime.timedelta(0, 44930), 3)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44930), datetime.timedelta(0, 44930), 3)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44941), datetime.timedelta(0, 44941), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44941), datetime.timedelta(0, 44941), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44941), datetime.timedelta(0, 44941), 3)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44941), datetime.timedelta(0, 44941), 3)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44942), datetime.timedelta(0, 44947), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44942), datetime.timedelta(0, 44942), 3)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44948), datetime.timedelta(0, 44948), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44948), datetime.timedelta(0, 44948), 3)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44948), datetime.timedelta(0, 44948), 3)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44949), datetime.timedelta(0, 44949), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44949), datetime.timedelta(0, 44961), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44949), datetime.timedelta(0, 44949), 3)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44961), datetime.timedelta(0, 44961), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44961), datetime.timedelta(0, 44961), 3)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44962), datetime.timedelta(0, 44962), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44962), datetime.timedelta(0, 44962), 3)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44962), datetime.timedelta(0, 44963), 3)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44963), datetime.timedelta(0, 44963), 2)
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44963), datetime.timedelta(0, 44963), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45239), datetime.timedelta(0, 45269), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45269), datetime.timedelta(0, 45273), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45273), datetime.timedelta(0, 45274), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45273), datetime.timedelta(0, 45273), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45274), datetime.timedelta(0, 45275), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45274), datetime.timedelta(0, 45274), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45275), datetime.timedelta(0, 45275), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45276), datetime.timedelta(0, 45277), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45277), datetime.timedelta(0, 45278), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45278), datetime.timedelta(0, 45306), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45306), datetime.timedelta(0, 45307), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45307), datetime.timedelta(0, 45307), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45307), datetime.timedelta(0, 45308), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45307), datetime.timedelta(0, 45307), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45308), datetime.timedelta(0, 45313), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45313), datetime.timedelta(0, 45315), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45315), datetime.timedelta(0, 45343), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45343), datetime.timedelta(0, 45344), 1)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45344), datetime.timedelta(0, 45347), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45348), datetime.timedelta(0, 45354), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45354), datetime.timedelta(0, 45358), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45359), datetime.timedelta(0, 45363), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45364), datetime.timedelta(0, 45370), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45370), datetime.timedelta(0, 45373), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45373), datetime.timedelta(0, 45373), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45373), datetime.timedelta(0, 45374), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45373), datetime.timedelta(0, 45373), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45373), datetime.timedelta(0, 45373), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45374), datetime.timedelta(0, 45376), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45376), datetime.timedelta(0, 45382), 1)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45382), datetime.timedelta(0, 45382), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45382), datetime.timedelta(0, 45382), 1)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45383), datetime.timedelta(0, 45386), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45386), datetime.timedelta(0, 45407), 1)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45407), datetime.timedelta(0, 45446), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45446), datetime.timedelta(0, 45448), 1)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45448), datetime.timedelta(0, 45449), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45449), datetime.timedelta(0, 45452), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45452), datetime.timedelta(0, 45453), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45452), datetime.timedelta(0, 45452), 1)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45453), datetime.timedelta(0, 45499), 1)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45499), datetime.timedelta(0, 45503), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45503), datetime.timedelta(0, 45504), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45504), datetime.timedelta(0, 45505), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45505), datetime.timedelta(0, 45506), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45506), datetime.timedelta(0, 45512), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45512), datetime.timedelta(0, 45512), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45512), datetime.timedelta(0, 45513), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45513), datetime.timedelta(0, 45519), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45519), datetime.timedelta(0, 45519), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45520), datetime.timedelta(0, 45525), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45525), datetime.timedelta(0, 45554), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45554), datetime.timedelta(0, 45562), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45562), datetime.timedelta(0, 45580), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45581), datetime.timedelta(0, 45629), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46024), datetime.timedelta(0, 46054), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46054), datetime.timedelta(0, 46088), 0)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46089), datetime.timedelta(0, 46134), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46134), datetime.timedelta(0, 46151), 0)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46151), datetime.timedelta(0, 46151), 0)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46151), datetime.timedelta(0, 46151), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46151), datetime.timedelta(0, 46153), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46153), datetime.timedelta(0, 46153), 0)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46153), datetime.timedelta(0, 46163), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46163), datetime.timedelta(0, 46165), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46165), datetime.timedelta(0, 46166), 1)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46166), datetime.timedelta(0, 46170), 0)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46170), datetime.timedelta(0, 46203), 1)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46203), datetime.timedelta(0, 46244), 0)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46244), datetime.timedelta(0, 46247), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46247), datetime.timedelta(0, 46247), 0)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46247), datetime.timedelta(0, 46248), 1)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46248), datetime.timedelta(0, 46248), 0)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46249), datetime.timedelta(0, 46287), 1)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46287), datetime.timedelta(0, 46289), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46290), datetime.timedelta(0, 46291), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46291), datetime.timedelta(0, 46297), 1)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46297), datetime.timedelta(0, 46297), 0)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46297), datetime.timedelta(0, 46298), 0)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46297), datetime.timedelta(0, 46297), 1)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46299), datetime.timedelta(0, 46319), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46319), datetime.timedelta(0, 46336), 0)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46336), datetime.timedelta(0, 46341), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46341), datetime.timedelta(0, 46342), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46342), datetime.timedelta(0, 46346), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46346), datetime.timedelta(0, 46346), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46347), datetime.timedelta(0, 46347), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46347), datetime.timedelta(0, 46377), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46347), datetime.timedelta(0, 46347), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46377), datetime.timedelta(0, 46378), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46378), datetime.timedelta(0, 46380), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46380), datetime.timedelta(0, 46385), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46385), datetime.timedelta(0, 46385), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46385), datetime.timedelta(0, 46391), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46385), datetime.timedelta(0, 46385), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46391), datetime.timedelta(0, 46409), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46409), datetime.timedelta(0, 46409), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46409), datetime.timedelta(0, 46409), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46409), datetime.timedelta(0, 46409), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46410), datetime.timedelta(0, 46411), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46412), datetime.timedelta(0, 46412), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46412), datetime.timedelta(0, 46412), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46412), datetime.timedelta(0, 46412), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46412), datetime.timedelta(0, 46414), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46414), datetime.timedelta(0, 46415), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46415), datetime.timedelta(0, 46415), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46415), datetime.timedelta(0, 46415), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46416), datetime.timedelta(0, 46417), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46417), datetime.timedelta(0, 46417), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46417), datetime.timedelta(0, 46418), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46418), datetime.timedelta(0, 46418), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46418), datetime.timedelta(0, 46418), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46419), datetime.timedelta(0, 46419), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46419), datetime.timedelta(0, 46419), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46419), datetime.timedelta(0, 46419), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46419), datetime.timedelta(0, 46420), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46420), datetime.timedelta(0, 46425), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46425), datetime.timedelta(0, 46444), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46444), datetime.timedelta(0, 46444), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46445), datetime.timedelta(0, 46445), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46445), datetime.timedelta(0, 46445), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46445), datetime.timedelta(0, 46448), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46448), datetime.timedelta(0, 46448), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46767), datetime.timedelta(0, 46797), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46797), datetime.timedelta(0, 46798), 0)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46798), datetime.timedelta(0, 46800), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46800), datetime.timedelta(0, 46801), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46801), datetime.timedelta(0, 46801), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46802), datetime.timedelta(0, 46839), 0)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46802), datetime.timedelta(0, 46802), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46839), datetime.timedelta(0, 46880), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46880), datetime.timedelta(0, 46881), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46881), datetime.timedelta(0, 46881), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46881), datetime.timedelta(0, 46886), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46881), datetime.timedelta(0, 46881), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46886), datetime.timedelta(0, 46895), 0)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46886), datetime.timedelta(0, 46886), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46886), datetime.timedelta(0, 46886), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46895), datetime.timedelta(0, 46898), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46898), datetime.timedelta(0, 46901), 0)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46901), datetime.timedelta(0, 46944), 1)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46944), datetime.timedelta(0, 46988), 0)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46988), datetime.timedelta(0, 46991), 1)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46991), datetime.timedelta(0, 46992), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46992), datetime.timedelta(0, 46992), 1)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46992), datetime.timedelta(0, 46994), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46995), datetime.timedelta(0, 46996), 0)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46996), datetime.timedelta(0, 47001), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47001), datetime.timedelta(0, 47032), 1)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47033), datetime.timedelta(0, 47033), 1)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47033), datetime.timedelta(0, 47033), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47033), datetime.timedelta(0, 47035), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47036), datetime.timedelta(0, 47041), 0)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47041), datetime.timedelta(0, 47043), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47044), datetime.timedelta(0, 47050), 0)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47050), datetime.timedelta(0, 47053), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47054), datetime.timedelta(0, 47084), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47084), datetime.timedelta(0, 47088), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47084), datetime.timedelta(0, 47084), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47088), datetime.timedelta(0, 47089), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47088), datetime.timedelta(0, 47088), 3)
# ...
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45307), datetime.timedelta(0, 45307), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45307), datetime.timedelta(0, 45307), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45307), datetime.timedelta(0, 45307), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45308), datetime.timedelta(0, 45308), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45308), datetime.timedelta(0, 45313), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45313), datetime.timedelta(0, 45316), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45316), datetime.timedelta(0, 45344), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45344), datetime.timedelta(0, 45344), 1)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45344), datetime.timedelta(0, 45348), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45348), datetime.timedelta(0, 45354), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45354), datetime.timedelta(0, 45359), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45359), datetime.timedelta(0, 45364), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45364), datetime.timedelta(0, 45371), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45371), datetime.timedelta(0, 45373), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45373), datetime.timedelta(0, 45373), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45373), datetime.timedelta(0, 45374), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45374), datetime.timedelta(0, 45374), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45374), datetime.timedelta(0, 45374), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45375), datetime.timedelta(0, 45376), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45376), datetime.timedelta(0, 45383), 1)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45383), datetime.timedelta(0, 45383), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45383), datetime.timedelta(0, 45383), 1)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45383), datetime.timedelta(0, 45387), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45387), datetime.timedelta(0, 45408), 1)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45408), datetime.timedelta(0, 45446), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45446), datetime.timedelta(0, 45449), 1)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45449), datetime.timedelta(0, 45450), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45450), datetime.timedelta(0, 45453), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45453), datetime.timedelta(0, 45453), 1)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45453), datetime.timedelta(0, 45453), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45453), datetime.timedelta(0, 45499), 1)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45500), datetime.timedelta(0, 45503), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45503), datetime.timedelta(0, 45505), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45505), datetime.timedelta(0, 45506), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45506), datetime.timedelta(0, 45506), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45506), datetime.timedelta(0, 45512), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45512), datetime.timedelta(0, 45512), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45513), datetime.timedelta(0, 45513), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45513), datetime.timedelta(0, 45519), 0)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45519), datetime.timedelta(0, 45520), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45520), datetime.timedelta(0, 45525), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45525), datetime.timedelta(0, 45555), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45555), datetime.timedelta(0, 45562), 3)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45562), datetime.timedelta(0, 45581), 2)
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45581), datetime.timedelta(0, 45629), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46025), datetime.timedelta(0, 46055), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46055), datetime.timedelta(0, 46089), 0)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46089), datetime.timedelta(0, 46135), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46135), datetime.timedelta(0, 46151), 0)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46152), datetime.timedelta(0, 46152), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46152), datetime.timedelta(0, 46152), 0)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46152), datetime.timedelta(0, 46153), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46153), datetime.timedelta(0, 46153), 0)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46154), datetime.timedelta(0, 46164), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46164), datetime.timedelta(0, 46165), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46165), datetime.timedelta(0, 46166), 1)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46166), datetime.timedelta(0, 46170), 0)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46170), datetime.timedelta(0, 46203), 1)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46203), datetime.timedelta(0, 46245), 0)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46245), datetime.timedelta(0, 46247), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46248), datetime.timedelta(0, 46248), 0)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46248), datetime.timedelta(0, 46249), 1)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46249), datetime.timedelta(0, 46249), 0)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46249), datetime.timedelta(0, 46287), 1)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46287), datetime.timedelta(0, 46290), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46290), datetime.timedelta(0, 46291), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46291), datetime.timedelta(0, 46297), 1)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46297), datetime.timedelta(0, 46297), 0)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46297), datetime.timedelta(0, 46297), 1)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46298), datetime.timedelta(0, 46299), 0)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46299), datetime.timedelta(0, 46320), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46320), datetime.timedelta(0, 46337), 0)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46337), datetime.timedelta(0, 46342), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46342), datetime.timedelta(0, 46342), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46343), datetime.timedelta(0, 46346), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46346), datetime.timedelta(0, 46347), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46347), datetime.timedelta(0, 46347), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46347), datetime.timedelta(0, 46347), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46347), datetime.timedelta(0, 46377), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46378), datetime.timedelta(0, 46379), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46379), datetime.timedelta(0, 46380), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46380), datetime.timedelta(0, 46385), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46385), datetime.timedelta(0, 46385), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46386), datetime.timedelta(0, 46386), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46386), datetime.timedelta(0, 46391), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46391), datetime.timedelta(0, 46409), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46410), datetime.timedelta(0, 46410), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46410), datetime.timedelta(0, 46410), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46410), datetime.timedelta(0, 46410), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46410), datetime.timedelta(0, 46412), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46412), datetime.timedelta(0, 46413), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46413), datetime.timedelta(0, 46413), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46413), datetime.timedelta(0, 46413), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46413), datetime.timedelta(0, 46415), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46415), datetime.timedelta(0, 46415), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46415), datetime.timedelta(0, 46416), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46416), datetime.timedelta(0, 46416), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46416), datetime.timedelta(0, 46417), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46417), datetime.timedelta(0, 46417), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46418), datetime.timedelta(0, 46418), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46418), datetime.timedelta(0, 46419), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46419), datetime.timedelta(0, 46419), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46419), datetime.timedelta(0, 46419), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46419), datetime.timedelta(0, 46419), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46419), datetime.timedelta(0, 46420), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46420), datetime.timedelta(0, 46420), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46420), datetime.timedelta(0, 46426), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46426), datetime.timedelta(0, 46445), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46445), datetime.timedelta(0, 46445), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46445), datetime.timedelta(0, 46445), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46445), datetime.timedelta(0, 46445), 2)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46446), datetime.timedelta(0, 46448), 3)
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46449), datetime.timedelta(0, 46449), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46768), datetime.timedelta(0, 46798), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46798), datetime.timedelta(0, 46799), 0)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46799), datetime.timedelta(0, 46800), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46800), datetime.timedelta(0, 46802), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46802), datetime.timedelta(0, 46802), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46802), datetime.timedelta(0, 46803), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46803), datetime.timedelta(0, 46840), 0)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46840), datetime.timedelta(0, 46881), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46881), datetime.timedelta(0, 46881), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46881), datetime.timedelta(0, 46882), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46882), datetime.timedelta(0, 46882), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46882), datetime.timedelta(0, 46886), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46886), datetime.timedelta(0, 46886), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46886), datetime.timedelta(0, 46887), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46887), datetime.timedelta(0, 46895), 0)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46896), datetime.timedelta(0, 46899), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46899), datetime.timedelta(0, 46902), 0)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46902), datetime.timedelta(0, 46945), 1)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46945), datetime.timedelta(0, 46989), 0)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46989), datetime.timedelta(0, 46991), 1)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46992), datetime.timedelta(0, 46992), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46993), datetime.timedelta(0, 46993), 1)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46993), datetime.timedelta(0, 46995), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46995), datetime.timedelta(0, 46996), 0)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46996), datetime.timedelta(0, 47001), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47001), datetime.timedelta(0, 47033), 1)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47033), datetime.timedelta(0, 47033), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47034), datetime.timedelta(0, 47034), 1)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47034), datetime.timedelta(0, 47036), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47036), datetime.timedelta(0, 47041), 0)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47041), datetime.timedelta(0, 47044), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47044), datetime.timedelta(0, 47050), 0)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47050), datetime.timedelta(0, 47054), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47054), datetime.timedelta(0, 47084), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47085), datetime.timedelta(0, 47085), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47085), datetime.timedelta(0, 47088), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47088), datetime.timedelta(0, 47088), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47088), datetime.timedelta(0, 47089), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47089), datetime.timedelta(0, 47089), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47089), datetime.timedelta(0, 47098), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47098), datetime.timedelta(0, 47131), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47131), datetime.timedelta(0, 47135), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47135), datetime.timedelta(0, 47135), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47135), datetime.timedelta(0, 47135), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47135), datetime.timedelta(0, 47136), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47136), datetime.timedelta(0, 47136), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47136), datetime.timedelta(0, 47145), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47145), datetime.timedelta(0, 47145), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47145), datetime.timedelta(0, 47146), 3)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47147), datetime.timedelta(0, 47147), 2)
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47147), datetime.timedelta(0, 47157), 3)

# %%
mycursor.execute("SELECT * FROM AllDaySummary")

myresult = mycursor.fetchall()

print(len(myresult))

for x in range(len(myresult)):
    print(myresult[x])
# Out:
# 8
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 46800), datetime.timedelta(0, 50400), datetime.timedelta(0, 36), datetime.timedelta(0), datetime.timedelta(0, 37), datetime.timedelta(0), 1, 0, 2, 0, 1, 2, 3, 2, datetime.timedelta(0, 1200))
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50400), datetime.timedelta(0, 54000), datetime.timedelta(0, 67), datetime.timedelta(0, 70), datetime.timedelta(0, 243), datetime.timedelta(0, 188), 16, 6, 88, 91, 22, 179, 201, 32, datetime.timedelta(0, 17))
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36000), datetime.timedelta(0, 39600), datetime.timedelta(0, 116), datetime.timedelta(0, 68), datetime.timedelta(0, 181), datetime.timedelta(0, 63), 12, 9, 32, 19, 21, 51, 72, 31, datetime.timedelta(0, 50))
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 43200), datetime.timedelta(0, 46800), datetime.timedelta(0, 68), datetime.timedelta(0, 70), datetime.timedelta(0, 169), datetime.timedelta(0, 30), 6, 4, 25, 20, 10, 45, 55, 14, datetime.timedelta(0, 65))
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 43200), datetime.timedelta(0, 46800), datetime.timedelta(0, 92), datetime.timedelta(0, 76), datetime.timedelta(0, 129), datetime.timedelta(0, 86), 15, 7, 19, 14, 22, 33, 55, 24, datetime.timedelta(0, 65))
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 43200), datetime.timedelta(0, 46800), datetime.timedelta(0, 114), datetime.timedelta(0, 79), datetime.timedelta(0, 163), datetime.timedelta(0, 58), 11, 6, 27, 24, 17, 51, 68, 16, datetime.timedelta(0, 52))
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 43200), datetime.timedelta(0, 46800), datetime.timedelta(0, 1), datetime.timedelta(0), datetime.timedelta(0, 32), datetime.timedelta(0), 1, 0, 2, 0, 1, 2, 3, 2, datetime.timedelta(0, 1200))
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46800), datetime.timedelta(0, 50400), datetime.timedelta(0, 105), datetime.timedelta(0, 77), datetime.timedelta(0, 107), datetime.timedelta(0, 60), 7, 5, 20, 16, 12, 36, 48, 18, datetime.timedelta(0, 75))

# %%
mycursor.execute("DELETE FROM Patient")

# %%
# mycursor.execute("DROP TABLE AllDaySummary")
# mycursor.execute("DROP TABLE ActivityPeriod")
# mycursor.execute("DROP TABLE Patient")

# mycursor.execute("DROP DATABASE amd_project")
