# %% [markdown]
# # Import Libraries

# %%
import mysql.connector

# %%
import pickle
import ruptures as rpt
import sklearn

from prettytable import PrettyTable

# %% [markdown]
# # Connect to MySQL Database

# %%
mydb = mysql.connector.connect(
    host='localhost',
    user='root',
    passwd='slow675',
    database='amd_project'
    )

# %%
print(mydb)
# Out:
# <mysql.connector.connection.MySQLConnection object at 0x1a14a25e80>

# %%
mycursor = mydb.cursor()

# %% [markdown]
# # Load Dataset

# %%
# %run data_cleanse.ipynb
# Out:
# Loading 2001's data
# Loading 3001's data
# Loading 3002's data
# Loading 3003's data
# Loading 3004's data
# Loading 3005's data
# Finished Loading

# %% [markdown]
# # Predict Labels

# %%
# %run predict.ipynb

# %% [markdown]
# # Analyze Predicted Results

# %%
# %run summarize.ipynb
# Out:
# summarize.ipynb:18: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   "import matplotlib.pyplot as plt\n",

# %%
df_all_p_sorted
# Out:
#          ID                timestamp         x         y         z         HR
# 0      2001  2019-01-16 13:58:47.956  0.246041  0.475436  0.576183  68.205284
# 1      2001  2019-01-16 13:58:48.117  0.246431  0.473881  0.576429  68.205284
# 2      2001  2019-01-16 13:58:48.278  0.246236  0.474464  0.573722  68.205284
# 3      2001  2019-01-16 13:58:48.439  0.246041  0.473881  0.574460  67.365480
# 4      2001    2019-01-16 13:58:48.6  0.246821  0.472521  0.575444  67.365480
# 5      2001   2019-01-16 13:58:48.76  0.247016  0.474659  0.572246  67.365480
# 6      2001  2019-01-16 13:58:48.922  0.247211  0.477574  0.573722  67.365480
# 7      2001   2019-01-16 13:58:49.08  0.245262  0.469994  0.575198  67.365480
# 8      2001  2019-01-16 13:58:49.243  0.246041  0.475047  0.571754  67.365480
# 9      2001  2019-01-16 13:58:49.402  0.246236  0.471937  0.570277  67.365480
# 10     2001  2019-01-16 13:58:49.562  0.246041  0.473492  0.571508  66.945570
# 11     2001  2019-01-16 13:58:49.723  0.242144  0.472326  0.572984  66.945570
# 12     2001  2019-01-16 13:58:49.884  0.245457  0.472132  0.570770  66.945570
# 13     2001  2019-01-16 13:58:50.045  0.246236  0.475047  0.570277  66.945570
# 14     2001  2019-01-16 13:58:50.205  0.243703  0.477185  0.573968  66.945570
# 15     2001  2019-01-16 13:58:50.366  0.244677  0.477963  0.567817  66.945570
# 16     2001  2019-01-16 13:58:50.526  0.245067  0.475436  0.573476  66.945570
# 17     2001  2019-01-16 13:58:50.687  0.245262  0.483211  0.566341  66.891680
# 18     2001  2019-01-16 13:58:50.848  0.247016  0.473492  0.572000  66.891680
# 19     2001  2019-01-16 13:58:51.009  0.244482  0.471743  0.572738  66.891680
# 20     2001  2019-01-16 13:58:51.169  0.244482  0.470966  0.573968  66.891680
# 21     2001  2019-01-16 13:58:51.332  0.244872  0.472715  0.570523  66.891680
# 22     2001   2019-01-16 13:58:51.49  0.247406  0.473492  0.569785  66.891680
# 23     2001  2019-01-16 13:58:51.651  0.245652  0.472326  0.574214  66.891680
# 24     2001  2019-01-16 13:58:51.812  0.246626  0.473881  0.567817  66.883880
# 25     2001  2019-01-16 13:58:51.972  0.245067  0.474076  0.570770  66.883880
# 26     2001  2019-01-16 13:58:52.134  0.244677  0.470382  0.572246  66.883880
# 27     2001  2019-01-16 13:58:52.294  0.243703  0.475825  0.572492  66.883880
# 28     2001  2019-01-16 13:58:52.454  0.242923  0.470188  0.574460  66.883880
# 29     2001  2019-01-16 13:58:52.615  0.244872  0.479518  0.571262  66.883880
# ...     ...                      ...       ...       ...       ...        ...
# 16548  3005  2019-03-05 13:05:52.444  0.765662  0.479994  0.751300  85.435660
# 16549  3005  2019-03-05 13:05:52.605  0.714778  0.467301  0.768947  85.435660
# 16550  3005  2019-03-05 13:05:52.766  0.762793  0.439432  0.640416  85.435660
# 16551  3005  2019-03-05 13:05:52.928  0.653754  0.412941  0.620136  85.435660
# 16552  3005  2019-03-05 13:05:53.087  0.839885  0.377070  0.647001  85.435660
# 16553  3005  2019-03-05 13:05:53.249  0.860545  0.404939  0.722592  85.435660
# 16554  3005  2019-03-05 13:05:53.409  0.712865  0.466198  0.723645  83.078640
# 16555  3005  2019-03-05 13:05:53.568  0.755141  0.535458  0.802924  83.078640
# 16556  3005   2019-03-05 13:05:53.73  0.779627  0.487997  0.693093  83.078640
# 16557  3005  2019-03-05 13:05:53.889  0.741176  0.399696  0.570356  83.078640
# 16558  3005  2019-03-05 13:05:54.051  0.656815  0.404111  0.612234  83.078640
# 16559  3005  2019-03-05 13:05:54.211  0.785748  0.424531  0.616448  83.078640
# 16560  3005  2019-03-05 13:05:54.372  0.934577  0.481374  0.745769  83.078640
# 16561  3005  2019-03-05 13:05:54.532  0.682257  0.503449  0.683874  80.898530
# 16562  3005  2019-03-05 13:05:54.692  0.762984  0.548427  0.681241  80.898530
# 16563  3005  2019-03-05 13:05:54.854  0.773505  0.475028  0.652005  80.898530
# 16564  3005  2019-03-05 13:05:55.014  0.787853  0.499586  0.558504  80.898530
# 16565  3005  2019-03-05 13:05:55.175  0.663319  0.471440  0.585632  80.898530
# 16566  3005  2019-03-05 13:05:55.335  0.695265  0.458471  0.645420  80.898530
# 16567  3005  2019-03-05 13:05:55.496  0.701961  0.483858  0.701521  80.898530
# 16568  3005  2019-03-05 13:05:55.657  0.710187  0.529939  0.666754  68.207535
# 16569  3005  2019-03-05 13:05:55.818  0.723003  0.516418  0.678607  68.207535
# 16570  3005  2019-03-05 13:05:55.978  0.936490  0.537666  0.617502  68.207535
# 16571  3005  2019-03-05 13:05:56.137  0.817121  0.506760  0.591427  68.207535
# 16572  3005  2019-03-05 13:05:56.302  0.689144  0.430877  0.584842  68.207535
# 16573  3005  2019-03-05 13:05:56.459  0.715352  0.433637  0.600909  68.207535
# 16574  3005  2019-03-05 13:05:56.621  0.920995  0.515039  0.654902  68.207535
# 16575  3005  2019-03-05 13:05:56.781  0.835103  0.460955  0.671495  68.207535
# 16576  3005  2019-03-05 13:05:56.941  0.726447  0.516970  0.653059  68.207535
# 16577  3005  2019-03-05 13:05:57.101  0.774462  0.524972  0.650161  68.207535
#
# [16578 rows x 6 columns]

# %% [markdown]
# # Insert to Database

# %%
sql = "INSERT INTO Patient (ID, Dateandtime, X, Y, Z, HR, Label) \
    VALUES (%s, %s, %s, %s, %s, %s, %s)"

for row in zip(df_all_p_sorted['ID'], 
               df_all_p_sorted['timestamp'], 
               df_all_p_sorted['x'], 
               df_all_p_sorted['y'], 
               df_all_p_sorted['z'], 
               df_all_p_sorted['HR'], 
               df_all_p_sorted['y_pred']):
    
    mycursor.execute(sql, row)

mydb.commit()

# %%
sql = "INSERT INTO AllDaySummary (ID, Date, TimeFrom, TimeUntil,\
    DurationSit, DurationSleep, DurationStand, DurationWalk,\
    CountSit, CountSleep, CountStand, CountWalk,\
    CountActive, CountInactive,\
    CountTotalActiveness, CountTransition, DurationPerTransition)\
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s,\
    # %s, %s, %s, %s, %s, %s, %s, %s)"

for row in zip(df_summary_all['ID'], 
               df_summary_all['date'], 
               df_summary_all['from'],
               df_summary_all['to'], 
               df_summary_all['sit'], 
               df_summary_all['sleep'], 
               df_summary_all['stand'],
               df_summary_all['walk'],
               df_summary_all['sit count'], 
               df_summary_all['sleep count'], 
               df_summary_all['stand count'], 
               df_summary_all['walk count'], 
               df_summary_all['inactive count'], 
               df_summary_all['active count'], 
               df_summary_all['total count'], 
               df_summary_all['transition count'], 
               df_summary_all['duration per action']):
    
    mycursor.execute(sql, row)
    
mydb.commit()

# %%
sql = "INSERT INTO ActivityPeriod (ID, Date, TimeFrom, TimeUntil, Label)\
    VALUES (%s, %s, %s, %s, %s)"

for row in zip(df_act_period['ID'], 
               df_act_period['date'], 
               df_act_period['from'],
               df_act_period['to'],
               df_act_period['y_pred']):
    
    mycursor.execute(sql, row)

mydb.commit()

# %% [markdown]
# # Show Results

# %%
mycursor.execute("SELECT * FROM Patient")

myresult = mycursor.fetchall()

print(len(myresult))

for x in range(50):
    print(myresult[x])
# Out:
# 16578
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 47), '956', 0.246, 0.4754, 0.5762, 68.2053, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 48), '117', 0.2464, 0.4739, 0.5764, 68.2053, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 48), '278', 0.2462, 0.4745, 0.5737, 68.2053, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 48), '439', 0.246, 0.4739, 0.5745, 67.3655, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 48), '6', 0.2468, 0.4725, 0.5754, 67.3655, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 48), '76', 0.247, 0.4747, 0.5722, 67.3655, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 48), '922', 0.2472, 0.4776, 0.5737, 67.3655, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 49), '08', 0.2453, 0.47, 0.5752, 67.3655, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 49), '243', 0.246, 0.475, 0.5718, 67.3655, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 49), '402', 0.2462, 0.4719, 0.5703, 67.3655, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 49), '562', 0.246, 0.4735, 0.5715, 66.9456, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 49), '723', 0.2421, 0.4723, 0.573, 66.9456, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 49), '884', 0.2455, 0.4721, 0.5708, 66.9456, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 50), '045', 0.2462, 0.475, 0.5703, 66.9456, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 50), '205', 0.2437, 0.4772, 0.574, 66.9456, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 50), '366', 0.2447, 0.478, 0.5678, 66.9456, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 50), '526', 0.2451, 0.4754, 0.5735, 66.9456, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 50), '687', 0.2453, 0.4832, 0.5663, 66.8917, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 50), '848', 0.247, 0.4735, 0.572, 66.8917, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 51), '009', 0.2445, 0.4717, 0.5727, 66.8917, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 51), '169', 0.2445, 0.471, 0.574, 66.8917, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 51), '332', 0.2449, 0.4727, 0.5705, 66.8917, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 51), '49', 0.2474, 0.4735, 0.5698, 66.8917, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 51), '651', 0.2457, 0.4723, 0.5742, 66.8917, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 51), '812', 0.2466, 0.4739, 0.5678, 66.8839, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 51), '972', 0.2451, 0.4741, 0.5708, 66.8839, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 52), '134', 0.2447, 0.4704, 0.5722, 66.8839, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 52), '294', 0.2437, 0.4758, 0.5725, 66.8839, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 52), '454', 0.2429, 0.4702, 0.5745, 66.8839, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 52), '615', 0.2449, 0.4795, 0.5713, 66.8839, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 52), '775', 0.2453, 0.4745, 0.5745, 66.8839, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 52), '936', 0.2468, 0.4782, 0.5752, 67.4191, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 53), '097', 0.2451, 0.4807, 0.5767, 67.4191, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 53), '259', 0.2453, 0.4764, 0.5705, 67.4191, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 53), '418', 0.2462, 0.4764, 0.571, 67.4191, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 53), '58', 0.2443, 0.4784, 0.5757, 67.4191, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 53), '739', 0.246, 0.4764, 0.5698, 67.4191, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 53), '902', 0.2439, 0.4766, 0.57, 67.4191, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 54), '08', 0.2453, 0.4743, 0.5725, 67.6867, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 54), '222', 0.2464, 0.4743, 0.5678, 67.6867, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 54), '382', 0.2449, 0.4747, 0.57, 67.6867, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 54), '542', 0.2439, 0.4749, 0.5683, 67.6867, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 54), '703', 0.2443, 0.4719, 0.5722, 67.6867, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 54), '864', 0.2472, 0.4745, 0.5715, 67.6867, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 55), '029', 0.247, 0.476, 0.5722, 67.8205, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 55), '185', 0.2468, 0.4737, 0.575, 67.8205, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 55), '345', 0.2484, 0.4684, 0.5713, 67.8205, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 55), '506', 0.2451, 0.4789, 0.5737, 67.8205, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 55), '668', 0.249, 0.4688, 0.5678, 67.8205, None)
# (2001, datetime.datetime(2019, 1, 16, 13, 58, 55), '828', 0.2492, 0.4696, 0.571, 67.8205, None)

# %%
mycursor.execute("SELECT * FROM ActivityPeriod")

myresult = mycursor.fetchall()

print(len(myresult))

for x in range(len(myresult)):
    print(myresult[x])
# Out:
# 505
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50327), datetime.timedelta(0, 50362), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50362), datetime.timedelta(0, 50398), 'sit')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50398), datetime.timedelta(0, 50400), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50400), datetime.timedelta(0, 50436), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50436), datetime.timedelta(0, 50438), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50438), datetime.timedelta(0, 50443), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50443), datetime.timedelta(0, 50443), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50444), datetime.timedelta(0, 50444), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50444), datetime.timedelta(0, 50446), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50444), datetime.timedelta(0, 50444), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50447), datetime.timedelta(0, 50454), 'sit')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50447), datetime.timedelta(0, 50447), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50447), datetime.timedelta(0, 50447), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50454), datetime.timedelta(0, 50461), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50461), datetime.timedelta(0, 50462), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50462), datetime.timedelta(0, 50463), 'sit')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50464), datetime.timedelta(0, 50467), 'sleep')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50467), datetime.timedelta(0, 50469), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50469), datetime.timedelta(0, 50473), 'sit')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50473), datetime.timedelta(0, 50474), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50474), datetime.timedelta(0, 50481), 'sit')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50481), datetime.timedelta(0, 50482), 'sleep')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50482), datetime.timedelta(0, 50482), 'sit')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50483), datetime.timedelta(0, 50486), 'sit')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50483), datetime.timedelta(0, 50483), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50486), datetime.timedelta(0, 50487), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50487), datetime.timedelta(0, 50493), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50493), datetime.timedelta(0, 50493), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50494), datetime.timedelta(0, 50524), 'sleep')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50524), datetime.timedelta(0, 50526), 'sit')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50527), datetime.timedelta(0, 50528), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50529), datetime.timedelta(0, 50533), 'sit')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50533), datetime.timedelta(0, 50535), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50535), datetime.timedelta(0, 50564), 'sit')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50564), datetime.timedelta(0, 50565), 'sleep')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50565), datetime.timedelta(0, 50568), 'sit')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50568), datetime.timedelta(0, 50570), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50570), datetime.timedelta(0, 50571), 'sleep')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50571), datetime.timedelta(0, 50579), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50580), datetime.timedelta(0, 50614), 'sleep')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50614), datetime.timedelta(0, 50622), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50622), datetime.timedelta(0, 50627), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50622), datetime.timedelta(0, 50622), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50627), datetime.timedelta(0, 50627), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50627), datetime.timedelta(0, 50627), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50627), datetime.timedelta(0, 50627), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50628), datetime.timedelta(0, 50628), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50628), datetime.timedelta(0, 50629), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50629), datetime.timedelta(0, 50630), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50630), datetime.timedelta(0, 50655), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50630), datetime.timedelta(0, 50630), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50655), datetime.timedelta(0, 50656), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50656), datetime.timedelta(0, 50656), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50656), datetime.timedelta(0, 50659), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50660), datetime.timedelta(0, 50660), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50660), datetime.timedelta(0, 50660), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50660), datetime.timedelta(0, 50660), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50660), datetime.timedelta(0, 50661), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50661), datetime.timedelta(0, 50661), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50661), datetime.timedelta(0, 50663), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50661), datetime.timedelta(0, 50661), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50663), datetime.timedelta(0, 50674), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50663), datetime.timedelta(0, 50663), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50674), datetime.timedelta(0, 50675), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50675), datetime.timedelta(0, 50676), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50676), datetime.timedelta(0, 50677), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50676), datetime.timedelta(0, 50676), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50677), datetime.timedelta(0, 50679), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50677), datetime.timedelta(0, 50677), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50679), datetime.timedelta(0, 50679), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50679), datetime.timedelta(0, 50679), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50679), datetime.timedelta(0, 50706), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50706), datetime.timedelta(0, 50706), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50706), datetime.timedelta(0, 50708), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50708), datetime.timedelta(0, 50708), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50708), datetime.timedelta(0, 50708), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50709), datetime.timedelta(0, 50709), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50709), datetime.timedelta(0, 50732), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50732), datetime.timedelta(0, 50732), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50732), datetime.timedelta(0, 50734), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50734), datetime.timedelta(0, 50734), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50734), datetime.timedelta(0, 50734), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50734), datetime.timedelta(0, 50734), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50735), datetime.timedelta(0, 50735), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50735), datetime.timedelta(0, 50735), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50735), datetime.timedelta(0, 50738), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50739), datetime.timedelta(0, 50739), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50739), datetime.timedelta(0, 50740), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50740), datetime.timedelta(0, 50741), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50741), datetime.timedelta(0, 50741), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50741), datetime.timedelta(0, 50741), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50741), datetime.timedelta(0, 50741), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50742), datetime.timedelta(0, 50742), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50743), datetime.timedelta(0, 50743), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50743), datetime.timedelta(0, 50743), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50743), datetime.timedelta(0, 50744), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50744), datetime.timedelta(0, 50755), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50755), datetime.timedelta(0, 50756), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50756), datetime.timedelta(0, 50758), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50758), datetime.timedelta(0, 50759), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50758), datetime.timedelta(0, 50758), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50759), datetime.timedelta(0, 50833), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50759), datetime.timedelta(0, 50759), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50834), datetime.timedelta(0, 50834), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50834), datetime.timedelta(0, 50834), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50834), datetime.timedelta(0, 50834), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50834), datetime.timedelta(0, 50834), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50834), datetime.timedelta(0, 50846), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50846), datetime.timedelta(0, 50846), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50846), datetime.timedelta(0, 50846), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50847), datetime.timedelta(0, 50847), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50847), datetime.timedelta(0, 50848), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50848), datetime.timedelta(0, 50849), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50850), datetime.timedelta(0, 50850), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50850), datetime.timedelta(0, 50850), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50850), datetime.timedelta(0, 50850), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50850), datetime.timedelta(0, 50850), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50851), datetime.timedelta(0, 50851), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50851), datetime.timedelta(0, 50851), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50851), datetime.timedelta(0, 50851), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50851), datetime.timedelta(0, 50851), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50851), datetime.timedelta(0, 50851), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50851), datetime.timedelta(0, 50851), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50851), datetime.timedelta(0, 50863), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50863), datetime.timedelta(0, 50866), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50866), datetime.timedelta(0, 50866), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50866), datetime.timedelta(0, 50866), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50867), datetime.timedelta(0, 50868), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50868), datetime.timedelta(0, 50868), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50869), datetime.timedelta(0, 50869), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50869), datetime.timedelta(0, 50872), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50869), datetime.timedelta(0, 50869), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50869), datetime.timedelta(0, 50869), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50872), datetime.timedelta(0, 50873), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50873), datetime.timedelta(0, 50873), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50873), datetime.timedelta(0, 50873), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50873), datetime.timedelta(0, 50873), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50873), datetime.timedelta(0, 50873), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50874), datetime.timedelta(0, 50874), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50874), datetime.timedelta(0, 50875), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50876), datetime.timedelta(0, 50881), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50881), datetime.timedelta(0, 50882), 'sit')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50882), datetime.timedelta(0, 50895), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50895), datetime.timedelta(0, 50896), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50896), datetime.timedelta(0, 50901), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50902), datetime.timedelta(0, 50902), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50902), datetime.timedelta(0, 50906), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50906), datetime.timedelta(0, 50908), 'sit')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50908), datetime.timedelta(0, 50923), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50923), datetime.timedelta(0, 50934), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50934), datetime.timedelta(0, 50934), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50934), datetime.timedelta(0, 50934), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50934), datetime.timedelta(0, 50934), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50934), datetime.timedelta(0, 50934), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50935), datetime.timedelta(0, 50935), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50935), datetime.timedelta(0, 50935), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50935), datetime.timedelta(0, 50936), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50936), datetime.timedelta(0, 50936), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50936), datetime.timedelta(0, 50936), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50937), datetime.timedelta(0, 50937), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50937), datetime.timedelta(0, 50937), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50937), datetime.timedelta(0, 50938), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50937), datetime.timedelta(0, 50937), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50937), datetime.timedelta(0, 50937), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50938), datetime.timedelta(0, 50939), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50939), datetime.timedelta(0, 50939), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50939), datetime.timedelta(0, 50940), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50939), datetime.timedelta(0, 50939), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50940), datetime.timedelta(0, 50941), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50941), datetime.timedelta(0, 50941), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50941), datetime.timedelta(0, 50941), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50941), datetime.timedelta(0, 50941), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50941), datetime.timedelta(0, 50942), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50942), datetime.timedelta(0, 50945), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50945), datetime.timedelta(0, 50945), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50946), datetime.timedelta(0, 50946), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50946), datetime.timedelta(0, 50947), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50946), datetime.timedelta(0, 50946), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50947), datetime.timedelta(0, 50947), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50947), datetime.timedelta(0, 50947), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50948), datetime.timedelta(0, 50948), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50948), datetime.timedelta(0, 50948), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50949), datetime.timedelta(0, 50949), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50949), datetime.timedelta(0, 50949), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50949), datetime.timedelta(0, 50956), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50956), datetime.timedelta(0, 50956), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50956), datetime.timedelta(0, 50958), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50958), datetime.timedelta(0, 50958), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50958), datetime.timedelta(0, 50959), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50959), datetime.timedelta(0, 50964), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50964), datetime.timedelta(0, 50966), 'sit')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50966), datetime.timedelta(0, 50973), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50973), datetime.timedelta(0, 50973), 'sit')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50973), datetime.timedelta(0, 50975), 'sit')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50973), datetime.timedelta(0, 50973), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50975), datetime.timedelta(0, 50976), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50975), datetime.timedelta(0, 50975), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50976), datetime.timedelta(0, 50980), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50981), datetime.timedelta(0, 50981), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50981), datetime.timedelta(0, 50983), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50983), datetime.timedelta(0, 50984), 'stand')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50984), datetime.timedelta(0, 50993), 'walk')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50993), datetime.timedelta(0, 50993), 'sit')
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50993), datetime.timedelta(0, 50998), 'walk')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36204), datetime.timedelta(0, 36246), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36246), datetime.timedelta(0, 36288), 'sit')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36289), datetime.timedelta(0, 36328), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36329), datetime.timedelta(0, 36329), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36329), datetime.timedelta(0, 36338), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36329), datetime.timedelta(0, 36329), 'walk')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36329), datetime.timedelta(0, 36329), 'walk')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36338), datetime.timedelta(0, 36347), 'sit')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36347), datetime.timedelta(0, 36350), 'sleep')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36350), datetime.timedelta(0, 36354), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36354), datetime.timedelta(0, 36355), 'walk')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36355), datetime.timedelta(0, 36355), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36355), datetime.timedelta(0, 36355), 'walk')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36356), datetime.timedelta(0, 36358), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36358), datetime.timedelta(0, 36358), 'sleep')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36359), datetime.timedelta(0, 36387), 'sleep')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36359), datetime.timedelta(0, 36359), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36387), datetime.timedelta(0, 36395), 'sit')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36395), datetime.timedelta(0, 36396), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36396), datetime.timedelta(0, 36436), 'sit')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36436), datetime.timedelta(0, 36471), 'sleep')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36471), datetime.timedelta(0, 36474), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36474), datetime.timedelta(0, 36474), 'sit')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36474), datetime.timedelta(0, 36476), 'sleep')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36476), datetime.timedelta(0, 36482), 'sit')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36482), datetime.timedelta(0, 36488), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36488), datetime.timedelta(0, 36488), 'sit')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36488), datetime.timedelta(0, 36492), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36492), datetime.timedelta(0, 36492), 'sit')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36492), datetime.timedelta(0, 36492), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36493), datetime.timedelta(0, 36493), 'sit')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36493), datetime.timedelta(0, 36499), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36499), datetime.timedelta(0, 36499), 'walk')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36500), datetime.timedelta(0, 36500), 'sleep')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36500), datetime.timedelta(0, 36503), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36503), datetime.timedelta(0, 36503), 'sleep')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36503), datetime.timedelta(0, 36503), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36504), datetime.timedelta(0, 36507), 'walk')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36507), datetime.timedelta(0, 36544), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36544), datetime.timedelta(0, 36545), 'walk')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36545), datetime.timedelta(0, 36545), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36545), datetime.timedelta(0, 36545), 'walk')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36546), datetime.timedelta(0, 36549), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36549), datetime.timedelta(0, 36557), 'sit')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36557), datetime.timedelta(0, 36558), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36559), datetime.timedelta(0, 36559), 'sit')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36559), datetime.timedelta(0, 36562), 'sit')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36559), datetime.timedelta(0, 36559), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36562), datetime.timedelta(0, 36570), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36571), datetime.timedelta(0, 36582), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36571), datetime.timedelta(0, 36571), 'walk')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36582), datetime.timedelta(0, 36583), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36582), datetime.timedelta(0, 36582), 'walk')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36583), datetime.timedelta(0, 36583), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36583), datetime.timedelta(0, 36583), 'walk')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36584), datetime.timedelta(0, 36584), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36584), datetime.timedelta(0, 36584), 'walk')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36584), datetime.timedelta(0, 36584), 'walk')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36585), datetime.timedelta(0, 36586), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36587), datetime.timedelta(0, 36587), 'walk')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36588), datetime.timedelta(0, 36588), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36588), datetime.timedelta(0, 36588), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36588), datetime.timedelta(0, 36588), 'walk')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36588), datetime.timedelta(0, 36640), 'walk')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36640), datetime.timedelta(0, 36640), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36640), datetime.timedelta(0, 36646), 'walk')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36646), datetime.timedelta(0, 36646), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36647), datetime.timedelta(0, 36647), 'sleep')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36647), datetime.timedelta(0, 36647), 'stand')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36647), datetime.timedelta(0, 36647), 'walk')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36647), datetime.timedelta(0, 36647), 'walk')
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36648), datetime.timedelta(0, 36648), 'sleep')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44617), datetime.timedelta(0, 44647), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44648), datetime.timedelta(0, 44648), 'sit')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44648), datetime.timedelta(0, 44649), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44649), datetime.timedelta(0, 44684), 'sit')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44684), datetime.timedelta(0, 44721), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44721), datetime.timedelta(0, 44723), 'walk')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44723), datetime.timedelta(0, 44725), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44726), datetime.timedelta(0, 44726), 'sit')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44726), datetime.timedelta(0, 44726), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44727), datetime.timedelta(0, 44729), 'sit')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44729), datetime.timedelta(0, 44730), 'sleep')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44731), datetime.timedelta(0, 44732), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44733), datetime.timedelta(0, 44766), 'sleep')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44766), datetime.timedelta(0, 44768), 'sit')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44768), datetime.timedelta(0, 44772), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44772), datetime.timedelta(0, 44773), 'sleep')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44773), datetime.timedelta(0, 44774), 'walk')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44774), datetime.timedelta(0, 44803), 'sit')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44803), datetime.timedelta(0, 44838), 'sleep')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44838), datetime.timedelta(0, 44883), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44883), datetime.timedelta(0, 44884), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44883), datetime.timedelta(0, 44883), 'walk')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44884), datetime.timedelta(0, 44888), 'walk')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44888), datetime.timedelta(0, 44892), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44892), datetime.timedelta(0, 44893), 'walk')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44893), datetime.timedelta(0, 44896), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44896), datetime.timedelta(0, 44900), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44896), datetime.timedelta(0, 44896), 'walk')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44900), datetime.timedelta(0, 44902), 'walk')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44902), datetime.timedelta(0, 44909), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44909), datetime.timedelta(0, 44928), 'walk')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44928), datetime.timedelta(0, 44930), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44930), datetime.timedelta(0, 44930), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44930), datetime.timedelta(0, 44941), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44930), datetime.timedelta(0, 44930), 'walk')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44930), datetime.timedelta(0, 44930), 'walk')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44941), datetime.timedelta(0, 44941), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44941), datetime.timedelta(0, 44941), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44941), datetime.timedelta(0, 44941), 'walk')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44941), datetime.timedelta(0, 44941), 'walk')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44942), datetime.timedelta(0, 44947), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44942), datetime.timedelta(0, 44942), 'walk')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44948), datetime.timedelta(0, 44948), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44948), datetime.timedelta(0, 44948), 'walk')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44948), datetime.timedelta(0, 44948), 'walk')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44949), datetime.timedelta(0, 44949), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44949), datetime.timedelta(0, 44961), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44949), datetime.timedelta(0, 44949), 'walk')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44961), datetime.timedelta(0, 44961), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44961), datetime.timedelta(0, 44961), 'walk')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44962), datetime.timedelta(0, 44962), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44962), datetime.timedelta(0, 44962), 'walk')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44962), datetime.timedelta(0, 44963), 'walk')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44963), datetime.timedelta(0, 44963), 'stand')
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 44963), datetime.timedelta(0, 44963), 'walk')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45239), datetime.timedelta(0, 45269), 'stand')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45269), datetime.timedelta(0, 45273), 'sit')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45273), datetime.timedelta(0, 45274), 'sit')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45273), datetime.timedelta(0, 45273), 'walk')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45274), datetime.timedelta(0, 45275), 'sit')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45274), datetime.timedelta(0, 45274), 'stand')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45275), datetime.timedelta(0, 45275), 'stand')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45276), datetime.timedelta(0, 45277), 'sit')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45277), datetime.timedelta(0, 45278), 'stand')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45278), datetime.timedelta(0, 45306), 'sit')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45306), datetime.timedelta(0, 45307), 'stand')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45307), datetime.timedelta(0, 45307), 'sit')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45307), datetime.timedelta(0, 45308), 'sit')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45307), datetime.timedelta(0, 45307), 'stand')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45308), datetime.timedelta(0, 45313), 'stand')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45313), datetime.timedelta(0, 45315), 'walk')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45315), datetime.timedelta(0, 45343), 'stand')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45343), datetime.timedelta(0, 45344), 'sleep')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45344), datetime.timedelta(0, 45347), 'walk')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45348), datetime.timedelta(0, 45354), 'stand')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45354), datetime.timedelta(0, 45358), 'walk')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45359), datetime.timedelta(0, 45363), 'stand')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45364), datetime.timedelta(0, 45370), 'walk')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45370), datetime.timedelta(0, 45373), 'stand')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45373), datetime.timedelta(0, 45373), 'stand')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45373), datetime.timedelta(0, 45374), 'stand')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45373), datetime.timedelta(0, 45373), 'walk')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45373), datetime.timedelta(0, 45373), 'walk')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45374), datetime.timedelta(0, 45376), 'walk')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45376), datetime.timedelta(0, 45382), 'sleep')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45382), datetime.timedelta(0, 45382), 'sit')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45382), datetime.timedelta(0, 45382), 'sleep')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45383), datetime.timedelta(0, 45386), 'sit')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45386), datetime.timedelta(0, 45407), 'sleep')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45407), datetime.timedelta(0, 45446), 'sit')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45446), datetime.timedelta(0, 45448), 'sleep')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45448), datetime.timedelta(0, 45449), 'walk')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45449), datetime.timedelta(0, 45452), 'sit')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45452), datetime.timedelta(0, 45453), 'sit')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45452), datetime.timedelta(0, 45452), 'sleep')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45453), datetime.timedelta(0, 45499), 'sleep')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45499), datetime.timedelta(0, 45503), 'sit')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45503), datetime.timedelta(0, 45504), 'stand')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45504), datetime.timedelta(0, 45505), 'walk')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45505), datetime.timedelta(0, 45506), 'stand')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45506), datetime.timedelta(0, 45512), 'walk')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45512), datetime.timedelta(0, 45512), 'sit')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45512), datetime.timedelta(0, 45513), 'stand')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45513), datetime.timedelta(0, 45519), 'sit')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45519), datetime.timedelta(0, 45519), 'stand')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45520), datetime.timedelta(0, 45525), 'walk')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45525), datetime.timedelta(0, 45554), 'stand')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45554), datetime.timedelta(0, 45562), 'walk')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45562), datetime.timedelta(0, 45580), 'stand')
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 45581), datetime.timedelta(0, 45629), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46024), datetime.timedelta(0, 46054), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46054), datetime.timedelta(0, 46088), 'sit')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46089), datetime.timedelta(0, 46134), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46134), datetime.timedelta(0, 46151), 'sit')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46151), datetime.timedelta(0, 46151), 'sit')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46151), datetime.timedelta(0, 46151), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46151), datetime.timedelta(0, 46153), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46153), datetime.timedelta(0, 46153), 'sit')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46153), datetime.timedelta(0, 46163), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46163), datetime.timedelta(0, 46165), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46165), datetime.timedelta(0, 46166), 'sleep')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46166), datetime.timedelta(0, 46170), 'sit')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46170), datetime.timedelta(0, 46203), 'sleep')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46203), datetime.timedelta(0, 46244), 'sit')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46244), datetime.timedelta(0, 46247), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46247), datetime.timedelta(0, 46247), 'sit')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46247), datetime.timedelta(0, 46248), 'sleep')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46248), datetime.timedelta(0, 46248), 'sit')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46249), datetime.timedelta(0, 46287), 'sleep')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46287), datetime.timedelta(0, 46289), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46290), datetime.timedelta(0, 46291), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46291), datetime.timedelta(0, 46297), 'sleep')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46297), datetime.timedelta(0, 46297), 'sit')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46297), datetime.timedelta(0, 46298), 'sit')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46297), datetime.timedelta(0, 46297), 'sleep')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46299), datetime.timedelta(0, 46319), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46319), datetime.timedelta(0, 46336), 'sit')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46336), datetime.timedelta(0, 46341), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46341), datetime.timedelta(0, 46342), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46342), datetime.timedelta(0, 46346), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46346), datetime.timedelta(0, 46346), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46347), datetime.timedelta(0, 46347), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46347), datetime.timedelta(0, 46377), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46347), datetime.timedelta(0, 46347), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46377), datetime.timedelta(0, 46378), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46378), datetime.timedelta(0, 46380), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46380), datetime.timedelta(0, 46385), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46385), datetime.timedelta(0, 46385), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46385), datetime.timedelta(0, 46391), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46385), datetime.timedelta(0, 46385), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46391), datetime.timedelta(0, 46409), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46409), datetime.timedelta(0, 46409), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46409), datetime.timedelta(0, 46409), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46409), datetime.timedelta(0, 46409), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46410), datetime.timedelta(0, 46411), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46412), datetime.timedelta(0, 46412), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46412), datetime.timedelta(0, 46412), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46412), datetime.timedelta(0, 46412), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46412), datetime.timedelta(0, 46414), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46414), datetime.timedelta(0, 46415), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46415), datetime.timedelta(0, 46415), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46415), datetime.timedelta(0, 46415), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46416), datetime.timedelta(0, 46417), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46417), datetime.timedelta(0, 46417), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46417), datetime.timedelta(0, 46418), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46418), datetime.timedelta(0, 46418), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46418), datetime.timedelta(0, 46418), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46419), datetime.timedelta(0, 46419), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46419), datetime.timedelta(0, 46419), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46419), datetime.timedelta(0, 46419), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46419), datetime.timedelta(0, 46420), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46420), datetime.timedelta(0, 46425), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46425), datetime.timedelta(0, 46444), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46444), datetime.timedelta(0, 46444), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46445), datetime.timedelta(0, 46445), 'stand')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46445), datetime.timedelta(0, 46445), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46445), datetime.timedelta(0, 46448), 'walk')
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 46448), datetime.timedelta(0, 46448), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46767), datetime.timedelta(0, 46797), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46797), datetime.timedelta(0, 46798), 'sit')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46798), datetime.timedelta(0, 46800), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46800), datetime.timedelta(0, 46801), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46801), datetime.timedelta(0, 46801), 'walk')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46802), datetime.timedelta(0, 46839), 'sit')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46802), datetime.timedelta(0, 46802), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46839), datetime.timedelta(0, 46880), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46880), datetime.timedelta(0, 46881), 'walk')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46881), datetime.timedelta(0, 46881), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46881), datetime.timedelta(0, 46886), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46881), datetime.timedelta(0, 46881), 'walk')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46886), datetime.timedelta(0, 46895), 'sit')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46886), datetime.timedelta(0, 46886), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46886), datetime.timedelta(0, 46886), 'walk')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46895), datetime.timedelta(0, 46898), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46898), datetime.timedelta(0, 46901), 'sit')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46901), datetime.timedelta(0, 46944), 'sleep')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46944), datetime.timedelta(0, 46988), 'sit')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46988), datetime.timedelta(0, 46991), 'sleep')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46991), datetime.timedelta(0, 46992), 'walk')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46992), datetime.timedelta(0, 46992), 'sleep')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46992), datetime.timedelta(0, 46994), 'walk')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46995), datetime.timedelta(0, 46996), 'sit')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46996), datetime.timedelta(0, 47001), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47001), datetime.timedelta(0, 47032), 'sleep')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47033), datetime.timedelta(0, 47033), 'sleep')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47033), datetime.timedelta(0, 47033), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47033), datetime.timedelta(0, 47035), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47036), datetime.timedelta(0, 47041), 'sit')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47041), datetime.timedelta(0, 47043), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47044), datetime.timedelta(0, 47050), 'sit')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47050), datetime.timedelta(0, 47053), 'walk')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47054), datetime.timedelta(0, 47084), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47084), datetime.timedelta(0, 47088), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47084), datetime.timedelta(0, 47084), 'walk')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47088), datetime.timedelta(0, 47089), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47088), datetime.timedelta(0, 47088), 'walk')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47089), datetime.timedelta(0, 47098), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47089), datetime.timedelta(0, 47089), 'walk')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47098), datetime.timedelta(0, 47130), 'walk')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47130), datetime.timedelta(0, 47134), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47134), datetime.timedelta(0, 47134), 'walk')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47135), datetime.timedelta(0, 47135), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47135), datetime.timedelta(0, 47135), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47135), datetime.timedelta(0, 47135), 'walk')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47135), datetime.timedelta(0, 47144), 'walk')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47145), datetime.timedelta(0, 47145), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47145), datetime.timedelta(0, 47146), 'walk')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47146), datetime.timedelta(0, 47146), 'stand')
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 47146), datetime.timedelta(0, 47157), 'walk')

# %%
mycursor.execute("SELECT * FROM AllDaySummary")

myresult = mycursor.fetchall()

print(len(myresult))

for x in range(len(myresult)):
    print(myresult[x])
# Out:
# 8
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 46800), datetime.timedelta(0, 50400), datetime.timedelta(0, 36), datetime.timedelta(0), datetime.timedelta(0, 37), datetime.timedelta(0), 1, 0, 2, 0, 1, 2, 3, 2, datetime.timedelta(0, 1200))
# (2001, datetime.date(2019, 1, 16), datetime.timedelta(0, 50400), datetime.timedelta(0, 54000), datetime.timedelta(0, 67), datetime.timedelta(0, 70), datetime.timedelta(0, 243), datetime.timedelta(0, 188), 16, 6, 88, 91, 22, 179, 201, 32, datetime.timedelta(0, 17))
# (3001, datetime.date(2019, 3, 5), datetime.timedelta(0, 36000), datetime.timedelta(0, 39600), datetime.timedelta(0, 116), datetime.timedelta(0, 68), datetime.timedelta(0, 181), datetime.timedelta(0, 63), 12, 9, 32, 19, 21, 51, 72, 31, datetime.timedelta(0, 50))
# (3002, datetime.date(2019, 3, 5), datetime.timedelta(0, 43200), datetime.timedelta(0, 46800), datetime.timedelta(0, 68), datetime.timedelta(0, 70), datetime.timedelta(0, 169), datetime.timedelta(0, 30), 6, 4, 25, 20, 10, 45, 55, 14, datetime.timedelta(0, 65))
# (3003, datetime.date(2019, 3, 5), datetime.timedelta(0, 43200), datetime.timedelta(0, 46800), datetime.timedelta(0, 92), datetime.timedelta(0, 76), datetime.timedelta(0, 129), datetime.timedelta(0, 86), 15, 7, 19, 14, 22, 33, 55, 24, datetime.timedelta(0, 65))
# (3004, datetime.date(2019, 3, 5), datetime.timedelta(0, 43200), datetime.timedelta(0, 46800), datetime.timedelta(0, 114), datetime.timedelta(0, 79), datetime.timedelta(0, 163), datetime.timedelta(0, 58), 11, 6, 27, 24, 17, 51, 68, 16, datetime.timedelta(0, 52))
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 43200), datetime.timedelta(0, 46800), datetime.timedelta(0, 1), datetime.timedelta(0), datetime.timedelta(0, 32), datetime.timedelta(0), 1, 0, 2, 0, 1, 2, 3, 2, datetime.timedelta(0, 1200))
# (3005, datetime.date(2019, 3, 5), datetime.timedelta(0, 46800), datetime.timedelta(0, 50400), datetime.timedelta(0, 105), datetime.timedelta(0, 77), datetime.timedelta(0, 107), datetime.timedelta(0, 60), 7, 5, 20, 16, 12, 36, 48, 18, datetime.timedelta(0, 75))

# %%
mycursor.execute("DELETE FROM Patient")

# %%
mycursor.execute("DROP TABLE AllDaySummary")
mycursor.execute("DROP TABLE ActivityPeriod")
mycursor.execute("DROP TABLE Patient")

# mycursor.execute("DROP DATABASE amd_project")
