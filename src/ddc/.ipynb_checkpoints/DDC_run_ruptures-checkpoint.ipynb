# %% [markdown]
# # Import Core Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import math
import pickle

from os import listdir, walk
from os.path import isfile, join

# %%
from detect_peaks import detect_peaks
import ruptures as rpt

# %% [markdown]
# # Load Dataset

# %%
# %run load_dataset.ipynb

# %%
subj_range = np.hstack((np.arange(1001,1013),np.arange(2002,2003)))

all_subjects = [str(i) for i in subj_range]

# %%
subj_range = np.hstack((np.arange(2001,2002),np.arange(3001,3006)))

all_patients = [str(i) for i in subj_range]

# %%
print(all_subjects)
print(all_patients)
# Out:
# ['1001', '1002', '1003', '1004', '1005', '1006', '1007', '1008', '1009', '1010', '1011', '1012', '2002']
# ['2001', '3001', '3002', '3003', '3004', '3005']

# %%
X_all_p, y_all_p, subj_all_p, ts_all_p, hr_all_p = load_all_data(all_patients)
# Out:
# Loading 2001's data
# Loading 3001's data
# Loading 3002's data
# Loading 3003's data
# Loading 3004's data
# Loading 3005's data
# Finished loading

# %%
X_all_p.shape
# Out:
# (10998, 3)

# %% [markdown]
# # Data Preprocessing

# %%
# %run preprocessing.ipynb

# %% [markdown]
# # Group Data by Label and Normalize Data

# %%
print(label_list)
print(label_dict)
# Out:
# ['sit', 'sleep', 'stand', 'walk']
# {'sit': 0, 'sleep': 1, 'stand': 2, 'walk': 3}

# %%
new_label_list = [0,1,2,3]
new_label_dict = {
    0: 'sit',
    1: 'sleep',
    2: 'stand',
    3: 'walk'
}

colors = ['r','g','b','navy','turquoise','darkorange']

# %%
# group X_all and y_all from load_dataset.ipynb by labels
X_label, y_label = label_grouping(X_all_p, y_all_p, subj_all_p, all_patients, new_label_list)

# normalize X_label
X_norm = normalize_data(X_label)

# %% [markdown]
# ## Show Plot for each Activity and Subject

# %%
# plot_all_label(X_label, y_all, new_label_list, new_label_dict)

# %% [markdown]
# # Calculate Roll, Pitch, Yaw

# %%
roll, pitch, yaw = calc_rpy(X_all_p, colors)
rpy_p = np.array([roll, pitch, yaw]).transpose()

print(rpy_p.shape, y_all_p.shape)
# Out:
# (10998, 3) (10998,)

# %% [markdown]
# # Apply PCA

# %%
# apply PCA and LDA to X_all and rpy
X_pca_p, pca_p = apply_pca(X_all_p, y_all_p, label_list)
# rpy_pca_p, pca_p = apply_pca(rpy_p, y_all_p, label_list)

# %% [markdown]
# # Reshape Data (Pure Label)

# %%
# print(rpy_pca_p.shape, y_all_p.shape, subj_all_p.shape)

# %%
# get label-separated X and y
X_pure, y_pure = prepare_pure_label(X_pca_p, y_all_p, subj_all_p, all_patients, new_label_list)
y_pure = y_pure.reshape((y_pure.shape[0],))

# %%
print(X_pure.shape, y_pure.shape)
# Out:
# (9582, 180) (9582,)

# %% [markdown]
# # Reshape Data (Impure Label)

# %%
X_impure, y_impure = prepare_impure_label(X_pca_p, y_all_p)

# %%
print(X_impure.shape, y_impure.shape)
# Out:
# (10939, 180) (10939,)

# %% [markdown]
# # Split Train and Test Set

# %%
# Split training data and testing data
X_train, X_test, y_train, y_test = train_test_split(X_pure, y_pure, test_size=0.2, random_state=42)

X_tr, X_te, y_tr, y_te = train_test_split(X_impure, y_impure, test_size=0.2, random_state=42)

print(X_tr.shape)
print(X_te.shape)
# Out:
# (8751, 180)
# (2188, 180)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (7665, 180)
# (1917, 180)

# %% [markdown]
# # K-Nearest Neighbors

# %%
nn_model = nn_classifier(X_train, y_train)
print("Finished training")
# Out:
# Finished training

# %%
filename = basepath + 'model/knn_model_patients.pkl'
pickle.dump(nn_model, open(filename, 'wb'))

# %%
y_pred = nn_model.predict(X_test)

# %%
nn_model_2 = nn_classifier(X_tr, y_tr)
print("Finished training")
# Out:
# Finished training

# %%
y_pred_2 = nn_model_2.predict(X_te)

# %% [markdown]
# ## Evaluation

# %%
# %run eval_score.ipynb

# %%
LABELS = ['sit','sleep','stand','walk']

# %%
acc = accuracy_score(y_test, y_pred)
print(acc)

show_conf_matrix(y_test, y_pred, LABELS)
show_clf_report(y_test, y_pred, LABELS)
# Out:
# 0.8998435054773083
#               precision    recall  f1-score   support
#
#          sit       0.99      1.00      1.00       391
#        sleep       1.00      1.00      1.00       378
#        stand       0.77      1.00      0.87       621
#         walk       1.00      0.64      0.78       527
#
#    micro avg       0.90      0.90      0.90      1917
#    macro avg       0.94      0.91      0.91      1917
# weighted avg       0.92      0.90      0.90      1917

# %%
acc = accuracy_score(y_te, y_pred_2)
print(acc)

show_conf_matrix(y_te, y_pred_2, LABELS)
show_clf_report(y_te, y_pred_2, LABELS)
# Out:
# 0.8930530164533821
#               precision    recall  f1-score   support
#
#          sit       0.95      1.00      0.97       432
#        sleep       0.99      0.99      0.99       445
#        stand       0.77      1.00      0.87       688
#         walk       1.00      0.64      0.78       623
#
#    micro avg       0.89      0.89      0.89      2188
#    macro avg       0.93      0.91      0.90      2188
# weighted avg       0.92      0.89      0.89      2188

# %% [markdown]
# # Walk Algorithm

# %%
# %run classifier_alg.ipynb

# %%
X_dict = {
    'id': subj_all_p,
    'x': [X_i[0] for X_i in X_all_p],
    'y': [X_i[1] for X_i in X_all_p],
    'z': [X_i[2] for X_i in X_all_p],
    'x_pca': [X_i_pca[0] for X_i_pca in X_pca_p],
    'y_pca': [X_i_pca[1] for X_i_pca in X_pca_p],
    'z_pca': [X_i_pca[2] for X_i_pca in X_pca_p],
    'label': y_all_p
}

df_rpy = pd.DataFrame(X_dict)

# %%
cols = ['x_pca', 'y_pca', 'z_pca']

df_pca = df_rpy[cols]     # patients

# %%
xyz_pca = np.array(df_pca.to_dict(orient='split')['data'])
dummy_y = np.array([-1 for i in range(len(xyz_pca))])

# %%
xyz_pca, y_temp = make_overlapping(xyz_pca, dummy_y)

# %%
xyz_pca.shape, df_pca.shape
# Out:
# ((10939, 60, 3), (10998, 3))

# %%
walk_pred = classify_walk_2(xyz_pca)
walk_pred = np.array(walk_pred)

# %%
walk_pred
# Out:
# array([0, 0, 0, ..., 3, 3, 3])

# %%
walk_pred = np.array(walk_pred)

walk_pred.shape
# Out:
# (10939,)

# %%
walk_actual = np.array([3 if (df_rpy.loc[i, 'label']==3) else 0 for i in range(len(df_rpy))])

walk_actual.shape
# Out:
# (10998,)

# %%
print(walk_actual)
# Out:
# [0 0 0 ... 3 3 3]

# %% [markdown]
# ## Walk Algorithm Evaluation

# %%
walk_lbl = ['NaN','walk']

# %%
acc = accuracy_score(walk_actual[:walk_pred.shape[0]], walk_pred)
print(acc)

show_conf_matrix(walk_actual[:walk_pred.shape[0]], walk_pred, walk_lbl)
show_clf_report(walk_actual[:walk_pred.shape[0]], walk_pred, walk_lbl)
# Out:
# 0.907944053386964
#               precision    recall  f1-score   support
#
#          NaN       0.96      0.90      0.93      7871
#         walk       0.79      0.92      0.85      3068
#
#    micro avg       0.91      0.91      0.91     10939
#    macro avg       0.88      0.91      0.89     10939
# weighted avg       0.92      0.91      0.91     10939

# %% [markdown]
# # Combine SVM and Walk Algorithm

# %%
X_test_new = get_inverse_X(X_test)

X_test_new
# Out:
# array([[[-2.97e-01,  7.00e-02, -3.24e-02],
#         [-2.69e-01,  1.01e-01, -2.82e-02],
#         [-2.45e-01,  8.60e-02, -1.92e-02],
#         ...,
#         [-3.67e-01,  1.06e-01, -3.88e-03],
#         [-2.62e-01,  7.82e-02,  1.04e-03],
#         [-2.57e-01,  9.54e-02,  3.12e-03]],
#
#        [[ 3.33e-01,  2.05e-01, -4.81e-02],
#         [ 3.31e-01,  2.05e-01, -4.73e-02],
#         [ 3.33e-01,  2.04e-01, -4.88e-02],
#         ...,
#         [ 3.30e-01,  2.05e-01, -4.66e-02],
#         [ 3.31e-01,  2.05e-01, -4.52e-02],
#         [ 3.32e-01,  2.04e-01, -4.47e-02]],
#
#        [[ 2.38e-01,  1.02e-01, -2.01e-02],
#         [ 2.04e-01,  8.94e-02,  6.47e-03],
#         [ 3.55e-01,  9.41e-02, -3.44e-02],
#         ...,
#         [ 3.18e-01,  5.72e-02, -4.29e-02],
#         [ 1.66e-01,  7.11e-02, -1.55e-02],
#         [ 2.08e-01,  7.71e-02, -1.74e-02]],
#
#        ...,
#
#        [[-1.80e-01,  1.85e-03, -1.29e-01],
#         [-1.79e-01,  8.81e-04, -1.29e-01],
#         [-1.80e-01,  3.46e-04, -1.31e-01],
#         ...,
#         [-1.77e-01,  2.19e-03, -1.28e-01],
#         [-1.77e-01,  2.08e-03, -1.30e-01],
#         [-1.78e-01,  1.55e-03, -1.31e-01]],
#
#        [[ 2.98e-01,  6.65e-02, -5.08e-02],
#         [ 2.37e-01,  7.51e-02, -3.29e-02],
#         [ 2.51e-01,  7.05e-02, -2.03e-02],
#         ...,
#         [ 2.78e-01,  1.05e-01, -2.14e-02],
#         [ 2.70e-01,  7.90e-02, -1.51e-02],
#         [ 2.64e-01,  4.72e-02, -1.82e-02]],
#
#        [[-2.51e-01,  5.16e-03, -1.88e-03],
#         [-2.50e-01,  6.63e-03, -2.69e-03],
#         [-2.49e-01,  4.50e-03, -9.85e-04],
#         ...,
#         [-2.44e-01,  5.81e-03,  5.48e-03],
#         [-2.47e-01,  3.07e-03,  6.87e-03],
#         [-2.49e-01,  2.28e-03,  2.84e-03]]])

# %%
walk_pred = classify_walk_2(X_test_new)

# %%
y_pred_new = combine_2(X_test_new, y_pred)

# %%
acc = accuracy_score(y_test, y_pred_new)
print(acc)

show_conf_matrix(y_test, y_pred_new, LABELS)
show_clf_report(y_test, y_pred_new, LABELS)
# Out:
# 0.9426186750130412
#               precision    recall  f1-score   support
#
#          sit       1.00      0.91      0.95       391
#        sleep       1.00      0.96      0.98       378
#        stand       0.97      0.93      0.95       621
#         walk       0.84      0.97      0.90       527
#
#    micro avg       0.94      0.94      0.94      1917
#    macro avg       0.95      0.94      0.95      1917
# weighted avg       0.95      0.94      0.94      1917

# %% [markdown]
# # Test Model with Some Subjects

# %%
# %run test_model.ipynb

# %%
filename = basepath + 'model/knn_model_patients.pkl'

model = pickle.load(open(filename,'rb'))

# %%
all_subjects = [str(i) for i in range(3001,3006)]

df_y_all = call_functions(all_subjects, pca_p)
# Out:
# Loading 3001's data
# Finished prediction
# 0 765
# 766 827
# 828 1149
# 1150 1376
# 1377 1674
# 1675 1695
# 1696 1717
# 1718 1742
# 1743 2111
# 2112 2177
# 0 765
# 766 827
# 828 1149
# 1150 1376
# 1377 1674
# 1675 1695
# 1696 1717
# 1718 1742
# 1743 2111
# 2112 2177
# 0.3258495145631068
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#          sit       1.00      0.44      0.61       374
#        sleep       0.25      1.00      0.40       374
#        stand       0.00      0.00      0.00       573
#         walk       0.00      0.00      0.00       327
#
#    micro avg       0.33      0.33      0.33      1648
#    macro avg       0.31      0.36      0.25      1648
# weighted avg       0.28      0.33      0.23      1648
#
# Loading 3002's data
# Finished prediction
# 0 663
# 664 901
# 902 1112
# 1113 1341
# 0 663
# 664 901
# 902 1112
# 1113 1341
# 0.06342364532019705
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#          sit       0.12      0.11      0.12       374
#        sleep       0.05      0.16      0.07       374
#        stand       0.00      0.00      0.00       561
#         walk       0.00      0.00      0.00       315
#
#    micro avg       0.06      0.06      0.06      1624
#    macro avg       0.04      0.07      0.05      1624
# weighted avg       0.04      0.06      0.04      1624
#
# Loading 3003's data
# Finished prediction
# 0.229064039408867
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#          sit       0.00      0.00      0.00       374
#        sleep       0.23      1.00      0.37       372
#        stand       0.00      0.00      0.00       558
#         walk       0.00      0.00      0.00       320
#
#    micro avg       0.23      0.23      0.23      1624
#    macro avg       0.06      0.25      0.09      1624
# weighted avg       0.05      0.23      0.09      1624
#
# Loading 3004's data
# Finished prediction
# 0 855
# 856 1064
# 1065 1365
# 1366 1594
# 0 855
# 856 1064
# 1065 1365
# 1366 1594
# 0.03314917127071823
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#          sit       0.00      0.00      0.00       374
#        sleep       0.04      0.14      0.06       380
#        stand       0.00      0.00      0.00       561
#         walk       0.00      0.00      0.00       314
#
#    micro avg       0.03      0.03      0.03      1629
#    macro avg       0.01      0.04      0.02      1629
# weighted avg       0.01      0.03      0.01      1629
#
# Loading 3005's data
# Finished prediction
# 0.2341343191620456
#               precision    recall  f1-score   support
#
#          sit       0.00      0.00      0.00       374
#        sleep       0.23      1.00      0.38       380
#        stand       0.00      0.00      0.00       561
#         walk       0.00      0.00      0.00       308
#
#    micro avg       0.23      0.23      0.23      1623
#    macro avg       0.06      0.25      0.09      1623
# weighted avg       0.05      0.23      0.09      1623
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
cols = ['x','y','z']
df_y_all
# Out:
#                      timestamp y_pred y_actual
# 0      2019-03-05 10:03:34.189      1        2
# 1      2019-03-05 10:03:34.347      1        2
# 2      2019-03-05 10:03:34.509      1        2
# 3       2019-03-05 10:03:34.67      1        2
# 4      2019-03-05 10:03:34.828      1        2
# 5       2019-03-05 10:03:34.99      1        2
# 6       2019-03-05 10:03:35.15      1        2
# 7      2019-03-05 10:03:35.312      1        2
# 8      2019-03-05 10:03:35.471      1        2
# 9      2019-03-05 10:03:35.633      1        2
# 10     2019-03-05 10:03:35.792      1        2
# 11     2019-03-05 10:03:35.952      1        2
# 12     2019-03-05 10:03:36.113      1        2
# 13     2019-03-05 10:03:36.273      1        2
# 14     2019-03-05 10:03:36.435      1        2
# 15     2019-03-05 10:03:36.599      1        2
# 16     2019-03-05 10:03:36.757      1        2
# 17     2019-03-05 10:03:36.917      1        2
# 18     2019-03-05 10:03:37.079      1        2
# 19     2019-03-05 10:03:37.237      1        2
# 20     2019-03-05 10:03:37.397      1        2
# 21     2019-03-05 10:03:37.558      1        2
# 22      2019-03-05 10:03:37.72      1        2
# 23     2019-03-05 10:03:37.879      1        2
# 24     2019-03-05 10:03:38.041      1        2
# 25     2019-03-05 10:03:38.202      1        2
# 26      2019-03-05 10:03:38.36      1        2
# 27     2019-03-05 10:03:38.523      1        2
# 28     2019-03-05 10:03:38.682      1        2
# 29     2019-03-05 10:03:38.842      1        2
# ...                        ...    ...      ...
# 12088  2019-03-05 13:05:52.444      1        3
# 12089  2019-03-05 13:05:52.605      1        3
# 12090  2019-03-05 13:05:52.766      1        3
# 12091  2019-03-05 13:05:52.928      1        3
# 12092  2019-03-05 13:05:53.087      1        3
# 12093  2019-03-05 13:05:53.249      1        3
# 12094  2019-03-05 13:05:53.409      1        3
# 12095  2019-03-05 13:05:53.568      1        3
# 12096   2019-03-05 13:05:53.73      1        3
# 12097  2019-03-05 13:05:53.889      1        3
# 12098  2019-03-05 13:05:54.051      1        3
# 12099  2019-03-05 13:05:54.211      1        3
# 12100  2019-03-05 13:05:54.372      1        3
# 12101  2019-03-05 13:05:54.532      1        3
# 12102  2019-03-05 13:05:54.692      1        3
# 12103  2019-03-05 13:05:54.854      1        3
# 12104  2019-03-05 13:05:55.014      1        3
# 12105  2019-03-05 13:05:55.175      1        3
# 12106  2019-03-05 13:05:55.335      1        3
# 12107  2019-03-05 13:05:55.496      1        3
# 12108  2019-03-05 13:05:55.657      1        3
# 12109  2019-03-05 13:05:55.818      1        3
# 12110  2019-03-05 13:05:55.978      1        3
# 12111  2019-03-05 13:05:56.137      1        3
# 12112  2019-03-05 13:05:56.302      1        3
# 12113  2019-03-05 13:05:56.459      1        3
# 12114  2019-03-05 13:05:56.621      1        3
# 12115  2019-03-05 13:05:56.781      1        3
# 12116  2019-03-05 13:05:56.941      1        3
# 12117  2019-03-05 13:05:57.101      1        3
#
# [12118 rows x 3 columns]

# %%
LABELS = ['sit', 'sleep', 'stand', 'walk']

df_y_notnull = df_y_all[df_y_all['y_pred']!=-1]
df_y_notnull = df_y_notnull.dropna()
df_y_notnull = df_y_notnull.reset_index(drop=True)

print(df_y_notnull.shape)

actual_y = list(df_y_notnull['y_actual'])
pred_y = list(df_y_notnull['y_pred'])

last = len(pred_y)

for i in range(len(pred_y)):
    if(pred_y[i]==-1):
        last = i
        break

pred_y = pred_y[:last]
actual_y = actual_y[:last]

acc = accuracy_score(actual_y, pred_y)
print(acc)

show_conf_matrix(actual_y, pred_y, LABELS)
show_clf_report(actual_y, pred_y, LABELS)

labels_list = [0,1,2,3]
report = classification_report(actual_y, pred_y, labels_list, output_dict=True)
print(report['macro avg'])
# Out:
# (8148, 3)
# 0.17746686303387335
#               precision    recall  f1-score   support
#
#          sit       0.24      0.11      0.15      1870
#        sleep       0.17      0.66      0.27      1880
#        stand       0.00      0.00      0.00      2814
#         walk       0.00      0.00      0.00      1584
#
#    micro avg       0.18      0.18      0.18      8148
#    macro avg       0.10      0.19      0.11      8148
# weighted avg       0.10      0.18      0.10      8148
#
# {'precision': 0.10332882665003856, 'recall': 0.19243372397314823, 'f1-score': 0.10544683216730946, 'support': 8148}
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# # Segmentation Using Ruptures

# %%
# %run test_model.ipynb

# %%
LABELS = label_list
LABELS
# Out:
# ['sit', 'sleep', 'stand', 'walk']

# %%
person_id = '3005'

print("Loading {0}'s data".format(person_id))

df_sid = load_actual_timer(person_id)
df_test = load_data(person_id, df_sid)

X_vis_imp, ts_list_imp = preprocess_data(df_test, None)
df_y = predict_combine(X_vis_imp, ts_list_imp)

df_test, df_y = prepare_actual_lb(df_test, df_y, df_sid)

actual_periods = get_actual_periods(df_test)
pred_periods = get_predicted_periods(df_y)
pp_all_run = postprocess_predicted(pred_periods, df_y)

df_y['y_pred'] = pd.Series(pp_all_run)
pp_periods = get_predicted_periods(df_y)
plot_highlighted(person_id, df_test, pred_periods, pp_periods, actual_periods)

cols = ['x','y','z']

df_xyz = df_test[cols]

X_one_person = df_xyz.to_dict(orient='split')['data']
X_one_person = np.array(X_one_person)

model_alg = "l1"
algo = rpt.Pelt(model=model_alg, min_size=3, jump=5).fit(X_one_person)

bkps = [100,200,300]
my_bkps = algo.predict(pen=250)

# show results
fig, ax = rpt.display(X_one_person, bkps, my_bkps, figsize=(10, 6))
plt.show()
# Out:
# Loading 3005's data
# Finished prediction

# %%
X_one_person = MinMaxScaler().fit_transform(X_one_person)

# %%
my_bkps_ = np.hstack(([0],my_bkps))

my_bkps_
# Out:
# array([   0,  215,  450,  740,  820, 1100, 1375, 1640, 1690, 2426])

# %%
filename = basepath + 'model/knn_model_split.pkl'

model = pickle.load(open(filename, 'rb'))

# %%
predicted = []
periods = []
window_length = 60

for i in range(len(my_bkps_)-1):
    if(my_bkps_[i+1]-my_bkps_[i]>=window_length):
        X_pred, y_ = prepare_impure_label(X_one_person[my_bkps_[i]:my_bkps_[i+1]+1], np.zeros(X_one_person.shape[0]))

        print(my_bkps_[i], my_bkps_[i+1], X_pred.shape)

        y_predict = model.predict(X_pred)
        y_predict = np.hstack(([y_predict[0] for i in range(window_length-2)], y_predict))

        predicted.append(y_predict)
    else:
        predicted.append([None for i in range(my_bkps_[i+1]-my_bkps_[i])])
        
    periods.append([my_bkps_[i], my_bkps_[i+1]])
# Out:
# 0 215 (157, 180)
# 215 450 (177, 180)
# 450 740 (232, 180)
# 740 820 (22, 180)
# 820 1100 (222, 180)
# 1100 1375 (217, 180)
# 1375 1640 (207, 180)
# 1690 2426 (677, 180)

# %%
predicted = np.hstack(predicted)
predicted.shape
# Out:
# (2425,)

# %%
df_pred = pd.DataFrame({
                        'timestamp': np.zeros(predicted.shape[0]),
                        'y_actual': predicted
                        })
pred_periods = get_actual_periods(df_pred)

# %%
color_list = ['indianred','khaki','lightgreen','skyblue']

f, ax = plt.subplots(figsize=(15,4))
ax = df_test.plot(y=['x','y','z'], figsize=(15,4), color=['r','g','b'])

# cnt = 0
# for item in pred_periods:
#     print(item[1], predicted[item[1]-2], color_list[predicted[item[1]-2]])
#     label = predicted[item[1]-2]
#     if(label!=-1):
#         if(cnt==0):
#             ax.axvspan(item[0], item[1], color=color_list[label], label=LABELS[label])
#             cnt = 1
#         else:
#             ax.axvspan(item[0], item[1], color=color_list[label])
            
for i in range(len(pred_periods)):
    cnt = 0
    for item in pred_periods[i]:
        label = predicted[item[1]-2]
        if(label!=-1):
            if(cnt==0):
                ax.axvspan(item[0], item[1], color=color_list[label], label=LABELS[label])
                cnt = 1
            else:
                ax.axvspan(item[0], item[1], color=color_list[label])
                
ax.legend(loc='upper right')
            
plt.show()

# %%
df_y['y_pred'] = pd.Series(predicted)

df_y
# Out:
#                     timestamp y_pred y_actual
# 0     2019-03-05 12:59:37.109      2        2
# 1     2019-03-05 12:59:37.271      2        2
# 2     2019-03-05 12:59:37.432      2        2
# 3     2019-03-05 12:59:37.592      2        2
# 4     2019-03-05 12:59:37.752      2        2
# 5     2019-03-05 12:59:37.914      2        2
# 6     2019-03-05 12:59:38.073      2        2
# 7     2019-03-05 12:59:38.247      2        2
# 8     2019-03-05 12:59:38.394      2        2
# 9     2019-03-05 12:59:38.555      2        2
# 10    2019-03-05 12:59:38.718      2        2
# 11    2019-03-05 12:59:38.878      2        2
# 12    2019-03-05 12:59:39.037      2        2
# 13    2019-03-05 12:59:39.199      2        2
# 14     2019-03-05 12:59:39.36      2        2
# 15    2019-03-05 12:59:39.519      2        2
# 16    2019-03-05 12:59:39.682      2        2
# 17    2019-03-05 12:59:39.839      2        2
# 18    2019-03-05 12:59:40.002      2        2
# 19    2019-03-05 12:59:40.171      2        2
# 20    2019-03-05 12:59:40.322      2        2
# 21    2019-03-05 12:59:40.485      2        2
# 22    2019-03-05 12:59:40.644      2        2
# 23    2019-03-05 12:59:40.806      2        2
# 24    2019-03-05 12:59:40.965      2        2
# 25    2019-03-05 12:59:41.127      2        2
# 26    2019-03-05 12:59:41.288      2        2
# 27    2019-03-05 12:59:41.449      2        2
# 28    2019-03-05 12:59:41.608      2        2
# 29     2019-03-05 12:59:41.77      2        2
# ...                       ...    ...      ...
# 2337  2019-03-05 13:05:52.444      3        3
# 2338  2019-03-05 13:05:52.605      3        3
# 2339  2019-03-05 13:05:52.766      3        3
# 2340  2019-03-05 13:05:52.928      3        3
# 2341  2019-03-05 13:05:53.087      3        3
# 2342  2019-03-05 13:05:53.249      3        3
# 2343  2019-03-05 13:05:53.409      3        3
# 2344  2019-03-05 13:05:53.568      3        3
# 2345   2019-03-05 13:05:53.73      3        3
# 2346  2019-03-05 13:05:53.889      3        3
# 2347  2019-03-05 13:05:54.051      3        3
# 2348  2019-03-05 13:05:54.211      3        3
# 2349  2019-03-05 13:05:54.372      3        3
# 2350  2019-03-05 13:05:54.532      3        3
# 2351  2019-03-05 13:05:54.692      3        3
# 2352  2019-03-05 13:05:54.854      3        3
# 2353  2019-03-05 13:05:55.014      3        3
# 2354  2019-03-05 13:05:55.175      3        3
# 2355  2019-03-05 13:05:55.335      3        3
# 2356  2019-03-05 13:05:55.496      3        3
# 2357  2019-03-05 13:05:55.657      3        3
# 2358  2019-03-05 13:05:55.818      3        3
# 2359  2019-03-05 13:05:55.978      3        3
# 2360  2019-03-05 13:05:56.137      3        3
# 2361  2019-03-05 13:05:56.302      3        3
# 2362  2019-03-05 13:05:56.459      3        3
# 2363  2019-03-05 13:05:56.621      3        3
# 2364  2019-03-05 13:05:56.781      3        3
# 2365  2019-03-05 13:05:56.941      3        3
# 2366  2019-03-05 13:05:57.101      3        3
#
# [2367 rows x 3 columns]

# %%
df_y = df_y.dropna()

y_test = df_y['y_actual'].values.tolist()
y_pred = df_y['y_pred'].values.tolist()

acc = accuracy_score(y_test, y_pred)
print(acc)

show_conf_matrix(y_test, y_pred, LABELS)
show_clf_report(y_test, y_pred, LABELS)
# Out:
# 0.7178065311152187
#               precision    recall  f1-score   support
#
#          sit       1.00      0.89      0.94       374
#        sleep       0.00      0.00      0.00       380
#        stand       0.72      0.98      0.83       561
#         walk       0.54      0.92      0.68       308
#
#    micro avg       0.72      0.72      0.72      1623
#    macro avg       0.56      0.70      0.61      1623
# weighted avg       0.58      0.72      0.63      1623
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# E:\ProgramData\Anaconda\lib\site-packages\sklearn\metrics\classification.py:1143: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
person_id = '3002'
s = person_id
print("Loading {0}'s data".format(s))

df_sid = load_actual_timer(s)
df_test = load_data(s, df_sid)

cols = ['x','y','z']

df_xyz = df_test[cols]

X_one_person = df_xyz.to_dict(orient='split')['data']
X_one_person = np.array(X_one_person)

model_alg = "l1"
algo = rpt.Pelt(model=model_alg, min_size=3, jump=5).fit(X_one_person)

bkps = [100,200,300]
my_bkps = algo.predict(pen=250)

# show results
fig, ax = rpt.display(X_one_person, bkps, my_bkps, figsize=(10, 6))
plt.show()
# Out:
# Loading 3002's data
